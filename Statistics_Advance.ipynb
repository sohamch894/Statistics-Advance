# %% [markdown]
# # Assignment Questions
#
# Theory Questions
#
# 1.What is hypothesis testing in statistics?
#
# Hypothesis testing is a statistical method used to make inferences or decisions about a population based on sample data. It helps determine whether a claim (hypothesis) about a population parameter is likely to be true or false.
#
# Key Steps in Hypothesis Testing:
# 1.State the Hypotheses
#
# Null Hypothesis ( 𝐻 0 H 0​): The default assumption (e.g., no effect, no difference).
#
# Alternative Hypothesis ( 𝐻 𝑎 H a​): The claim we want to test (e.g., there is an effect, a difference exists).
#
# 2.Choose the Significance Level ( 𝛼 α)
#
# Common choices: 0.05 (5%), 0.01 (1%)
#
# It represents the probability of rejecting 𝐻 0 H 0​when it is actually true (Type I error).
#
# 3.Select the Test and Compute the Test Statistic
#
# Choose a test (e.g., t-test, chi-square test, ANOVA) based on data type and hypothesis.
#
# Compute the test statistic, which measures how much the sample data deviates from 𝐻 0 H 0​.
#
# 4.Find the P-value or Critical Value
#
# P-value: Probability of obtaining a result as extreme as the observed one under 𝐻 0 H 0​.
#
# Compare with 𝛼 α: If p-value < 𝛼 α, reject 𝐻 0 H 0​; otherwise, fail to reject 𝐻 0 H 0​.
#
# 5.Draw a Conclusion
#
# If 𝐻 0 H 0​is rejected, evidence supports 𝐻 𝑎 H a​.
#
# If 𝐻 0 H 0​is not rejected, there is insufficient evidence to support 𝐻 𝑎 H a​.
#
# 2.What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
# The Null Hypothesis ( 𝐻 0 H 0​) and the Alternative Hypothesis ( 𝐻 𝑎 H a​or 𝐻 1 H 1​) are two competing statements in hypothesis testing.
#
# Null Hypothesis ( 𝐻 0 H 0​)
# The null hypothesis represents the default assumption that there is no effect, no difference, or no relationship in the population.
#
# It is what we assume to be true unless we have enough evidence to reject it.
#
# It is usually stated with "=" (equal sign), such as:
#
# Example: A company claims its battery lasts 10 hours on average. 𝐻 0 : 𝜇
# 10 (The average battery life is 10 hours) H 0​:μ=10(The average battery life is 10 hours)
#
# Alternative Hypothesis ( 𝐻 𝑎 H a​or 𝐻 1 H 1​)
# The alternative hypothesis is the claim we are testing. It suggests that there is an effect, a difference, or a relationship.
#
# It contradicts 𝐻 0 H 0​and is supported if we find significant evidence against 𝐻 0 H 0​.
#
# It often uses "≠", ">", or "<" signs:
#
# Example: If we suspect the battery life is different from 10 hours: 𝐻 𝑎 : 𝜇 ≠ 10 (The average battery life is not 10 hours) H a​:μ  =10(The average battery life is not 10 hours)
#
# 3.What is the significance level in hypothesis testing, and why is it important?
#
# Significance Level ( 𝛼 α) in Hypothesis Testing
# The significance level ( 𝛼 α) is the probability of rejecting the null hypothesis ( 𝐻 0 H 0​) when it is actually true. In other words, it represents the risk of making a Type I error (false positive).
#
# 1.Common Choices for 𝛼 α:
#
# 0.05 (5%) → Most commonly used in research
#
# 0.01 (1%) → Used for stricter testing (e.g., medical studies)
#
# 0.10 (10%) → Used in exploratory research where some risk of error is acceptable
#
# 2.Why is the Significance Level Important?
#
# Controls Type I Error: It limits the probability of mistakenly rejecting 𝐻 0 H 0​.
#
# Determines Decision Rule: If the p-value (calculated from sample data) is less than 𝛼 α, we reject 𝐻 0 H 0​.
#
# Affects Statistical Power: Lower 𝛼 α reduces the risk of Type I errors but increases the risk of Type II errors (failing to reject a false 𝐻 0 H 0​).
#
# 4.What does a P-value represent in hypothesis testing?
#
# What is a P-Value in Hypothesis Testing?
#
# The p-value is the probability of obtaining a test result at least as extreme as the observed one, assuming the null hypothesis ( 𝐻 0 H 0​) is true.
#
# Interpretation of P-Value:
#
# A small p-value (e.g., p < 0.05) suggests that the observed data is unlikely under 𝐻 0 H 0​, so we may reject 𝐻 0 H 0​.
#
# A large p-value (e.g., p > 0.05) suggests that the data is consistent with 𝐻 0 H 0​, so we fail to reject it.
#
# Key Points:
#
# P-value is NOT the probability that 𝐻 0 H 0​is true.
#
# It does NOT prove 𝐻 0 H 0​or 𝐻 𝑎 H a​, only provides evidence against 𝐻 0 H 0​.
#
# Lower p-values indicate stronger evidence against 𝐻 0 H 0​.
#
# Decision Rule Based on P-Value and Significance Level ( 𝛼 α)
#
# If p-value < 𝛼 α: Reject 𝐻 0 H 0​(significant result).
#
# If p-value ≥ 𝛼 α: Fail to reject 𝐻 0 H 0​(not enough evidence).
#
# 5.How do you interpret the P-value in hypothesis testing?
#
# How to Interpret the P-Value in Hypothesis Testing
#
# The p-value helps determine whether to reject the null hypothesis ( 𝐻 0 H 0​) based on the observed data. It represents the probability of obtaining a result at least as extreme as the observed one, assuming 𝐻 0 H 0​is true.
#
# 1. Decision Rule Based on P-Value
#
# If p-value < 𝛼 α (e.g., 0.05):
#
# The result is statistically significant.
#
# There is strong evidence against 𝐻 0 H 0​.
#
# We reject 𝐻 0 H 0​and support the alternative hypothesis ( 𝐻 𝑎 H a​).
#
# If p-value ≥ 𝛼 α (e.g., 0.05):
#
# The result is not statistically significant.
#
# The data does not provide enough evidence to reject 𝐻 0 H 0​.
#
# We fail to reject 𝐻 0 H 0​(but we don’t "accept" it).
#
# 2. Interpretation in Different Scenarios
#
# Example 1: Drug Effectiveness Study
# A new drug is tested to see if it lowers blood pressure more than a placebo.
#
# Null Hypothesis ( 𝐻 0 H 0​): The drug has no effect ( 𝜇
# 0 μ=0).
#
# Alternative Hypothesis ( 𝐻 𝑎 H a​): The drug reduces blood pressure ( 𝜇 < 0 μ<0).
#
# Results:
#
# p-value = 0.02, 𝛼 =0.05 α=0.05 → 0.02 < 0.05, so we reject 𝐻 0 H 0​.
#
# Interpretation: The drug significantly lowers blood pressure.
#
# p-value = 0.08, 𝛼 =0.05 α=0.05 → 0.08 > 0.05, so we fail to reject 𝐻 0 H 0​.
#
# Interpretation: There is not enough evidence to conclude the drug is effective.
#
# 3. Misconceptions About P-Values
#
# 🚫 P-value is NOT the probability that 𝐻 0 H 0​is true.
#
# 🚫 P-value is NOT the probability of making a mistake.
#
# 🚫 A high p-value does not prove 𝐻 0 H 0​; it just means insufficient evidence to reject it.
#
# ✅ A small p-value suggests strong evidence against 𝐻 0 H 0​, but results should also be considered in context (sample size, study design, effect size).
#
# 6.What are Type 1 and Type 2 errors in hypothesis testing?
#
# Type I and Type II Errors in Hypothesis Testing
#
# In hypothesis testing, errors occur when our conclusion about the null hypothesis ( 𝐻 0 H 0​) is incorrect. The two types of errors are:
#
# 1. Type I Error (False Positive)
#
# Occurs when we reject 𝐻 0 H 0​when it is actually true.
#
# It is like a false alarm—detecting an effect that doesn’t exist.
#
# The probability of making a Type I error is the significance level ( 𝛼 α), often set at 0.05 (5%).
#
# 🔹 Example:
#
# A drug company tests a new medicine to see if it lowers blood pressure.
#
# 𝐻 0 H 0​: The drug has no effect.
#
# 𝐻 𝑎 H a​: The drug lowers blood pressure.
#
# Type I Error: We conclude the drug works when it actually doesn’t.
#
# Consequence: Patients may take an ineffective drug, wasting money and risking side effects.
#
# 2. Type II Error (False Negative)
#
# Occurs when we fail to reject 𝐻 0 H 0​when it is actually false.
#
# It means missing a real effect—not detecting something that actually exists.
#
# The probability of making a Type II error is 𝛽 β, which depends on sample size and effect size.
#
# 🔹 Example:
#
# In the same drug study:
#
# 𝐻 0 H 0​: The drug has no effect.
#
# 𝐻 𝑎 H a​: The drug lowers blood pressure.
#
# Type II Error: We conclude the drug doesn’t work when it actually does.
#
# Consequence: A helpful drug is not approved, and patients miss out on treatment.
#
# 7.What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#
# Difference Between One-Tailed and Two-Tailed Tests in Hypothesis Testing
#
# When conducting hypothesis tests, we choose between a one-tailed or two-tailed test based on the research question and alternative hypothesis ( 𝐻 𝑎 H a​).
#
# 1. One-Tailed Test (Directional Test)
#
# A one-tailed test checks for an effect in only one direction (either greater than or less than a certain value).
#
# The alternative hypothesis ( 𝐻 𝑎 H a​) uses either
#
# (right-tailed) or
#
# < < (left-tailed).
#
# The rejection region is in one tail of the probability distribution.
# Example: Testing if a new drug increases blood pressure
#
# 𝐻 0 H 0​: The drug has no effect ( 𝜇
# 120 μ=120).
#
# 𝐻 𝑎 H a​: The drug increases blood pressure ( 𝜇
#
# 120 μ>120).
#
# We reject 𝐻 0 H 0​only if the test statistic is significantly higher than expected.
#
# 🔹 When to Use?
#
# When we are only interested in one direction (e.g., "is the new fertilizer better?" rather than "is it different?").
#
# 2. Two-Tailed Test (Non-Directional Test)
#
# A two-tailed test checks for an effect in both directions (greater or less than a value).
#
# The alternative hypothesis ( 𝐻 𝑎 H a​) uses ≠  = (not equal to).
#
# The rejection region is split into two tails of the probability distribution.
#
# Example: Testing if a machine produces parts with an average length of 10 cm
#
# 𝐻 0 H 0​: The average length is 10 cm ( 𝜇
# 10 μ=10).
#
# 𝐻 𝑎 H a​: The average length is not 10 cm ( 𝜇 ≠ 10 μ  =10).
#
# We reject 𝐻 0 H 0​if the test statistic is significantly higher or lower than expected.
#
# 🔹 When to Use?
#
# When we are interested in any difference, not just in one direction (e.g., "does the new teaching method change test scores?" rather than "does it only improve them?").
#
# 8.What is the Z-test, and when is it used in hypothesis testing?
#
# What is a Z-Test in Hypothesis Testing?
#
# A Z-test is a statistical test used to determine whether the mean of a sample differs significantly from a known population mean. It is based on the Z-score and follows a normal distribution.
#
# When to Use a Z-Test?
#
# ✅ 1. Large Sample Size ( 𝑛 ≥ 30 n≥30)
#
# The Central Limit Theorem ensures that the sample mean is normally distributed.
# ✅ 2. Population Variance ( 𝜎 2 σ 2 ) is Known
#
# If the population standard deviation ( 𝜎 σ) is unknown, a t-test is more appropriate.
# ✅ 3. Data Follows a Normal Distribution
#
# If the sample size is small, the data should be normally distributed.
# Types of Z-Tests
#
# 1.One-Sample Z-Test (Comparing a Sample Mean to a Population Mean)
#
# Used when testing whether the sample mean ( 𝑥 ˉ x ˉ ) is different from a known population mean ( 𝜇 0 μ 0​).
#
# Example: Testing if the average height of students in a school is different from the national average.
#
# 2.Two-Sample Z-Test (Comparing Two Sample Means)
#
# Used when comparing the means of two independent samples.
#
# Example: Comparing the average test scores of students from two different schools.
#
# 3.Z-Test for Proportions
#
# Used when comparing proportions instead of means.
#
# Example: Checking if the proportion of people who prefer Brand A is different from 50%.
#
# Z-Test Formula
#
# For a one-sample Z-test:
#
# Where:
#
# 𝑥 ˉ x ˉ
#
# = Sample mean 𝜇
# μ = Population mean 𝜎 σ
# = Population standard deviation 𝑛 n
# = Sample size
# For a two-sample Z-test:
#
# Example: One-Sample Z-Test
#
# A company claims that its light bulbs last 1,000 hours. A sample of 50 bulbs has an average lifespan of 980 hours, with a known population standard deviation of 60 hours. We test at 𝛼
# 0.05 α=0.05 whether the bulbs last significantly less than 1,000 hours.
#
# Using a Z-table, the p-value for 𝑍
# − 2.36 Z=−2.36 is 0.0091.
#
# Since 0.0091 < 0.05, we reject 𝐻 0 H 0​and conclude that the bulbs last significantly less than 1,000 hours.
#
# 9.How do you calculate the Z-score, and what does it represent in hypothesis testing?
#
# What is a Z-Score in Hypothesis Testing?
#
# A Z-score (also called the standard score) measures how many standard deviations a data point or sample mean is from the population mean. It helps determine how extreme an observation is compared to the expected distribution.
#
# In hypothesis testing, the Z-score is used in a Z-test to compare a sample mean to a population mean and determine statistical significance.
#
# How to Calculate the Z-Score?
#
# 1. For an Individual Data Point: 𝑍
# 𝑋 − 𝜇 𝜎 Z= σ X−μ​
#
# Where:
#
# X = Individual data point 𝜇
# μ = Population mean 𝜎
# σ = Population standard deviation
# 2. For a Sample Mean (Z-Test Formula):
#
# 𝑍
# 𝑥 ˉ − 𝜇 𝜎 𝑛 Z= n​
#
# σ​
#
# x ˉ −μ​
#
# Where:
#
# x ˉ = Sample mean 𝜇
# μ = Population mean 𝜎
# σ = Population standard deviation 𝑛
# n = Sample size
# 10.What is the T-distribution, and when should it be used instead of the normal distribution?
#
# What is the T-Distribution?
#
# The T-distribution (also called Student’s T-distribution) is a probability distribution used in hypothesis testing and confidence intervals when the sample size is small ( 𝑛 < 30 n<30) or the population standard deviation ( 𝜎 σ) is unknown.
#
# It is similar to the normal distribution but has heavier tails, meaning it accounts for more variability in small samples.
#
# When to Use the T-Distribution Instead of the Normal Distribution?
# ✅ Use the T-distribution when:
#
# The sample size is small ( 𝑛 < 30 n<30).
#
# The population standard deviation ( 𝜎 σ) is unknown and is estimated using the sample standard deviation ( 𝑠 s).
#
# The data is approximately normal (if the sample size is small).
#
# ✅ Use the Normal Distribution (Z-distribution) when:
#
# The sample size is large ( 𝑛 ≥ 30 n≥30), so the Central Limit Theorem applies.
#
# The population standard deviation ( 𝜎 σ) is known.
#
# Formula for the T-Statistic
#
# For a one-sample t-test, the test statistic is:
#
# 𝑇
# 𝑥 ˉ − 𝜇 𝑠 𝑛 T= n​
#
# s​
#
# x ˉ −μ​
#
# Where:
#
# 𝑥 ˉ
#
# x ˉ = Sample mean 𝜇
# μ = Population mean 𝑠
# s = Sample standard deviation (since 𝜎 σ is unknown) 𝑛
# n = Sample size The T-distribution depends on degrees of freedom ( 𝑑 𝑓 df), which is calculated as:
# 𝑑 𝑓
# 𝑛 − 1 df=n−1
#
# 11.What is the difference between a Z-test and a T-test?
#
# Difference Between Z-Test and T-Test in Hypothesis Testing
#
# The Z-test and T-test are both statistical methods used to test hypotheses about population parameters, especially the mean. However, they are used in different situations based on the sample size, knowledge of the population standard deviation, and the nature of the data.
#
# 1. Z-Test (Z-Score Test)
#
# When to Use:
#
# Sample Size: Large sample size ( 𝑛 ≥ 30 n≥30)
#
# Population Standard Deviation ( 𝜎 σ): Known
#
# Data Distribution: Assumed to be normally distributed (but less of an issue for large samples due to the Central Limit Theorem).
#
# Key Features:
#
# Population standard deviation ( 𝜎 σ) is known, so it uses the Z-distribution (normal distribution).
#
# Appropriate for large samples or when the population standard deviation is known.
#
# The test statistic is calculated using the population standard deviation.
#
# Z-Test Formula:
#
# 𝑍
# 𝑥 ˉ − 𝜇 𝜎 𝑛 Z= n​
#
# σ​
#
# x ˉ −μ​
#
# Where:
#
# 𝑥 ˉ x
#
# = Sample mean -𝜇 μ = Population mean -𝜎 σ = Population standard deviation -𝑛 n = Sample size
#
# 2. T-Test (Student’s T-Test)
#
# When to Use:
#
# Sample Size: Small sample size ( 𝑛 < 30 n<30)
#
# Population Standard Deviation ( 𝜎 σ): Unknown
#
# Data Distribution: The data is assumed to be normally distributed for small samples.
#
# Key Features:
#
# The population standard deviation ( 𝜎 σ) is unknown, so we use the sample standard deviation ( 𝑠 s) instead.
#
# Used primarily when the sample size is small and the population standard deviation is unknown.
#
# The test statistic is based on the T-distribution, which has heavier tails to account for more variability in small samples.
#
# T-Test Formula: 𝑇
# 𝑥 ˉ − 𝜇 𝑠 𝑛 T= n​
#
# s​
#
# x ˉ −μ​
#
# Where:
#
# 𝑥 ˉ x ˉ = Sample mean
# 𝜇 μ = Population mean
# 𝑠 s = Sample standard deviation (since
# 𝜎 σ is unknown)
# 𝑛 n = Sample size 𝑑 𝑓
# 𝑛1
# df=n−1 (degrees of freedom)
# When to Use Each Test
#
# Z-Test:
#
# Use when the sample size is large ( 𝑛 ≥ 30 n≥30) or when the population standard deviation ( 𝜎 σ) is known.
#
# Example: Testing the average income of a population with a large sample size where the population standard deviation is known.
#
# T-Test:
#
# Use when the sample size is small ( 𝑛 < 30 n<30) and the population standard deviation is unknown.
#
# Example: Testing the effectiveness of a new treatment using a small sample where the population variability is not known.
#
# 12.What is the T-test, and how is it used in hypothesis testing?
#
# What is a T-Test?
#
# A T-test is a type of statistical test used to compare the means of one or two groups and determine whether there is a statistically significant difference between them. It is commonly used in hypothesis testing when the sample size is small ( 𝑛 < 30 n<30) or when the population standard deviation ( 𝜎 σ) is unknown.
#
# The T-test is based on the T-distribution, which is bell-shaped but has heavier tails than the normal distribution. This accounts for more variability when working with smaller samples.
#
# Types of T-Tests
#
# 1.One-Sample T-Test
#
# Compares the sample mean to a known population mean to see if there is a significant difference.
#
# Hypotheses:
#
# 𝐻 0 H 0​: The sample mean is equal to the population mean ( 𝜇 0 μ 0​).
#
# 𝐻 𝑎 H a​: The sample mean is different from the population mean.
#
# Example: Testing if the average test score of a class is different from a national average.
#
# 2.Independent Two-Sample T-Test
#
# Compares the means of two independent samples to see if there is a significant difference between them.
#
# Hypotheses:
#
# 𝐻 0 H 0​: The means of the two groups are equal ( 𝜇 1
# 𝜇 2 μ 1​=μ 2​).
#
# 𝐻 𝑎 H a​: The means of the two groups are not equal ( 𝜇 1 ≠ 𝜇 2 μ 1​
#
#  =μ 2​).
#
# Example: Comparing the average heights of men and women in a population.
# 3.Paired Sample T-Test
#
# Compares the means of two related samples (paired data) to determine if there is a significant difference.
#
# Hypotheses:
#
# 𝐻 0 H 0​: The mean difference between the paired observations is zero.
#
# 𝐻 𝑎 H a​: The mean difference is not zero.
#
# Example: Testing if the average weight of people before and after a diet program changes.
#
# How is the T-Test Used in Hypothesis Testing?
#
# The T-test is used to assess whether the observed data provides enough evidence to reject the null hypothesis ( 𝐻 0 H 0​) in favor of the alternative hypothesis ( 𝐻 𝑎 H a​).
#
# Steps to Perform a T-Test:
#
# 1.State the hypotheses:
#
# For a one-sample t-test:
#
# 𝐻 0 H 0​: 𝜇
# 𝜇 0 μ=μ 0​(population mean is equal to a given value).
#
# 𝐻 𝑎 H a​: 𝜇 ≠ 𝜇 0 μ  =μ 0​(population mean is different from a given value).
#
# For a two-sample t-test:
#
# 𝐻 0 H 0​: 𝜇 1
# 𝜇 2 μ 1​=μ 2​(the means of both samples are equal).
#
# 𝐻 𝑎 H a​: 𝜇 1 ≠ 𝜇 2 μ 1​
#
#  =μ 2​(the means of both samples are different).
#
# Choose the significance level ( 𝛼 α):
#
# Typically, 𝛼
# 0.05 α=0.05, which corresponds to a 95% confidence level.
#
# Calculate the t-statistic:
#
# For a one-sample t-test:
#
# 𝑇
# 𝑥 ˉ − 𝜇 0 𝑠 𝑛 T= n​
#
# s​
#
# x ˉ −μ 0​
#
# ​
#
# Where:
#
# 𝑥 ˉ x ˉ = Sample mean
#
# 𝜇 0 μ 0​= Population mean
#
# 𝑠 s = Sample standard deviation
#
# 𝑛 n = Sample size
#
# For a two-sample t-test (assuming equal variance):
#
# 𝑇
# 𝑥 1 ˉ − 𝑥 2 ˉ 𝑠 1 2 𝑛 1 + 𝑠 2 2 𝑛 2 T= n 1​
#
# s 1 2​
#
# ​+ n 2​
#
# s 2 2​
#
# ​
#
# ​
#
# x 1​
#
# ˉ​− x 2​
#
# ˉ​
#
# ​
#
# Where:
#
# 𝑥 1 ˉ , 𝑥 2 ˉ x 1​
# ˉ​, x 2​= Sample means of group 1 and group 2
#
# 𝑠 1 , 𝑠 2 s 1​,s 2​= Sample standard deviations of group 1 and group 2
#
# 𝑛 1 , 𝑛 2 n 1​,n 2​= Sample sizes of group 1 and group 2
#
# 4.Determine the degrees of freedom (df):
#
# For a one-sample t-test: 𝑑 𝑓
# 𝑛 − 1 df=n−1
#
# For a two-sample t-test: 𝑑 𝑓
# 𝑛 1
#
# 𝑛 2 − 2 df=n 1​+n 2​−2
# 5.Find the critical t-value from the t-distribution table:
#
# Based on the degrees of freedom and the significance level ( 𝛼 α).
# 6.Compare the t-statistic with the critical value:
#
# If the absolute value of the t-statistic is greater than the critical t-value, reject the null hypothesis ( 𝐻 0 H 0​).
#
# If the absolute value of the t-statistic is less than the critical t-value, do not reject 𝐻 0 H 0​.
#
# 13.What is the relationship between Z-test and T-test in hypothesis testing?
#
# Relationship Between Z-Test and T-Test in Hypothesis Testing
#
# Both the Z-test and T-test are statistical tests used to compare sample data to a population parameter (typically the mean) in hypothesis testing. While they share many similarities, there are key differences that determine which test is appropriate to use. Here's a breakdown of the relationship and how they compare:
#
# 1. Similarities Between Z-Test and T-Test
#
# Purpose: Both tests are used to test hypotheses about population means and help determine whether the observed data is significantly different from the expected population parameter.
#
# Test Statistic: Both the Z-test and T-test calculate a test statistic (Z or T) that quantifies how far the sample mean is from the population mean in terms of standard errors.
#
# Hypothesis Testing: Both tests follow the same process for hypothesis testing:
#
# State the null hypothesis ( 𝐻 0 H 0​) and alternative hypothesis ( 𝐻 𝑎 H a​).
#
# Choose a significance level ( 𝛼 α).
#
# Calculate the test statistic.
#
# Compare the test statistic to the critical value or use the p-value to make a decision.
#
# Distribution: Both tests are based on probability distributions (Z-distribution for Z-test and T-distribution for T-test). The T-distribution is used for small samples, while the Z-distribution is used for large samples.
#
# 2.When to Use Z-Test vs. T-Test
#
# Z-Test:
#
# When sample size is large ( 𝑛 ≥ 30 n≥30): The Z-test is appropriate for large sample sizes because the Central Limit Theorem ensures that the sampling distribution of the sample mean will approach a normal distribution, even if the population itself is not normally distributed.
#
# When population standard deviation is known ( 𝜎 σ): If the population standard deviation is available, the Z-test is the most efficient test to use because it uses the exact standard deviation of the population.
#
# T-Test:
#
# When sample size is small ( 𝑛 < 30 n<30): The T-test is more appropriate for small samples because the sample standard deviation is used as an estimate of the population standard deviation, and the T-distribution compensates for this uncertainty with heavier tails.
#
# When population standard deviation is unknown: In most real-world situations, we don’t have access to the population standard deviation, so the T-test becomes the default choice when 𝜎 σ is unknown.
#
# 3.As Sample Size Increases, T-Test Approaches Z-Test
#
# Convergence: As the sample size increases, the T-distribution approaches the normal distribution, meaning that for large samples, the T-test results become nearly identical to the Z-test results.
#
# The heavier tails of the T-distribution adjust for the increased uncertainty in small samples, but as the sample size grows, this uncertainty reduces and the T-distribution becomes less "heavy," thus approaching the Z-distribution.
#
# 4 Example: Relationship Between Z-Test and T-Test
#
# Let’s say you are testing if the average height of a sample of 25 students is different from the national average of 170 cm. The sample standard deviation is 10 cm.
#
# If you knew the population standard deviation ( 𝜎
# 10 σ=10 cm): You would use a Z-test.
#
# If you didn’t know the population standard deviation and only had the sample standard deviation:
#
# You would use a T-test, as the sample size is small ( 𝑛 < 30 n<30) and 𝜎 σ is unknown.
#
# 14.What is a confidence interval, and how is it used to interpret statistical results?
#
# What is a Confidence Interval?
#
# A confidence interval (CI) is a range of values that is used to estimate an unknown population parameter, such as a population mean or proportion, based on sample data. The interval provides an estimate of where the true population parameter is likely to fall, given a certain level of confidence.
#
# A confidence interval is not a precise value, but rather a range, and it is associated with a confidence level (e.g., 95%, 99%) that expresses how confident we are that the interval contains the true parameter.
#
# How is a Confidence Interval Calculated?
#
# The formula for calculating a confidence interval typically depends on the sample mean ( 𝑥 ˉ x ˉ ), the standard deviation (or standard error), and the critical value (z-value or t-value), which depends on the desired confidence level.
#
# 1.Confidence Interval for a Population Mean (When Population Standard Deviation is Known) CI
# 𝑥 ˉ ± 𝑍 × 𝜎 𝑛 CI= x ˉ ±Z× n​
#
# σ​
#
# Where:
#
# 𝑥 ˉ x ˉ = Sample mean
# 𝑍 Z = Z-value corresponding to the desired confidence level (e.g., 1.96 for 95% confidence)
# 𝜎 σ = Population standard deviation
# 𝑛 n = Sample size
# 2.Confidence Interval for a Population Mean (When Population Standard Deviation is Unknown) CI
# 𝑥 ˉ ± 𝑡 × 𝑠 𝑛 CI= x ˉ ±t× n​
#
# s​
#
# Where:
#
# 𝑥 ˉ x ˉ = Sample mean
# 𝑡 t = t-value corresponding to the desired confidence level and degrees of freedom (from the t-distribution)
# 𝑠 s = Sample standard deviation
# 𝑛 n = Sample size
# 3. Confidence Interval for a Population Proportion CI
# 𝑝 ^ ± 𝑍 × 𝑝 ^ ( 1 − 𝑝 ^ ) 𝑛 CI= p ^​±Z× n p ^​(1− p ^​)​
#
# ​
#
# Where:
#
# 𝑝 ^ p ^​= Sample proportion
# 𝑍 Z = Z-value corresponding to the desired confidence level
# 𝑛 n = Sample size
# How is a Confidence Interval Interpreted?
#
# A confidence interval provides a range of plausible values for the population parameter. Here's how to interpret it:
#
# Confidence Level: The confidence level (e.g., 95%) means that if we were to take many random samples and construct a confidence interval from each sample, approximately 95% of those intervals would contain the true population parameter.
#
# Example: If we calculate a 95% confidence interval for the average height of students in a school as [160 cm, 165 cm], we can say that we are 95% confident that the true average height of all students in the school lies between 160 cm and 165 cm.
#
# Key Concepts Related to Confidence Intervals
#
# 1.Width of the Confidence Interval:
#
# The width of the confidence interval depends on several factors:
#
# The sample size ( 𝑛 n): Larger sample sizes reduce the width of the confidence interval because they provide more information about the population.
#
# The confidence level: A higher confidence level (e.g., 99%) results in a wider interval because it is giving a higher probability that the interval includes the true parameter.
#
# The standard deviation: A larger standard deviation will increase the interval width since the population is more spread out.
#
# 2.Increasing the Confidence Level:
#
# If you want a higher confidence level (e.g., 99% instead of 95%), the confidence interval will become wider because you are asking for a greater likelihood that the interval contains the true parameter.
# 3.Precision:
#
# A narrower confidence interval indicates more precise information about the population parameter.
#
# A wider confidence interval indicates more uncertainty and less precision about the true value of the parameter.
#
# Example of Interpreting a Confidence Interval
#
# Let’s say a poll is conducted to estimate the average salary of employees at a company. After surveying a random sample of 100 employees, the sample mean salary is found to be
# 10,000. Using a 95% confidence level, the confidence interval for the average salary is calculated as:
#
# CI
# 50 , 000 ± 1.96 × 10 , 000 100
# 50 , 000 ± 1.96 × 1 , 000
# 50 , 000 ± 1 , 960 CI=50,000±1.96× 100​
#
# 10,000​=50,000±1.96×1,000=50,000±1,960 So, the confidence interval is [
# 51,960].
#
# Interpretation: We are 95% confident that the true average salary of all employees at the company lies between
# 51,960.
#
# Confidence Intervals vs. Hypothesis Testing
#
# Confidence Intervals: Provide a range of values for a population parameter and allow you to assess the precision of the estimate.
#
# Hypothesis Testing: Involves testing a specific claim or hypothesis about a population parameter (e.g., is the mean salary equal to a certain value?).
#
# Both methods are related but serve different purposes in statistical analysis. Confidence intervals give you a range of plausible values, while hypothesis testing provides a decision about whether a hypothesis is supported by data.
#
# 15.What is the margin of error, and how does it affect the confidence interval?
#
# What is the Margin of Error?
#
# The margin of error (MOE) is a measure of the uncertainty or variability in an estimate. It represents the range above and below the sample statistic (e.g., the sample mean or sample proportion) within which we expect the true population parameter to lie, with a certain level of confidence. The margin of error is crucial for understanding how precise or reliable an estimate is.
#
# Mathematically, the margin of error is the amount added to and subtracted from the sample statistic to form the confidence interval.
#
# Margin of Error
# Critical Value × Standard Error Margin of Error=Critical Value×Standard Error
#
# Where:
#
# The critical value (e.g., Z-value or t-value) corresponds to the desired confidence level (e.g., 1.96 for 95% confidence).
#
# The standard error represents the standard deviation of the sampling distribution of the statistic (it is typically the standard deviation of the sample divided by the square root of the sample size).
#
# How the Margin of Error Affects the Confidence Interval
#
# The margin of error directly determines the width of the confidence interval. A larger margin of error results in a wider confidence interval, indicating greater uncertainty in the estimate. Conversely, a smaller margin of error results in a narrower confidence interval, indicating a more precise estimate of the population parameter.
#
# Formula for Confidence Interval using Margin of Error:
#
# Confidence Interval
# Sample Statistic ± Margin of Error Confidence Interval=Sample Statistic±Margin of Error
#
# Factors Affecting the Margin of Error
#
# 1.Sample Size ( 𝑛 n):
#
# The margin of error decreases (i.e., the estimate becomes more precise) as the sample size increases because the standard error decreases. A larger sample size provides more information about the population, which leads to a more accurate estimate. Standard Error
# 𝜎 𝑛 (for a known population standard deviation) Standard Error= n​
# σ​(for a known population standard deviation) or
#
# Standard Error
# 𝑠 𝑛 (for an unknown population standard deviation) Standard Error= n​
#
# s​(for an unknown population standard deviation)
#
# 2.Confidence Level:
#
# A higher confidence level (e.g., 99%) results in a larger critical value (Z or t-value), which increases the margin of error. This makes the confidence interval wider because you want to be more confident that the interval contains the true population parameter.
#
# A lower confidence level (e.g., 90%) results in a smaller critical value, leading to a smaller margin of error and a narrower confidence interval.
#
# 3.Variability of the Population:
#
# The standard deviation (or variability) of the population also affects the margin of error. If the population is highly variable, the margin of error will be larger, making the confidence interval wider.
# Example of Margin of Error in Action
#
# Let’s say you conduct a survey to estimate the average income of a population of workers. You sample 200 workers, and the sample mean income is
# 5,000. You want to calculate the 95% confidence interval for the population mean.
#
# Step 1: Find the Z-value for a 95% confidence level
# The Z-value for a 95% confidence level is 1.96.
#
# Step 2: Calculate the standard error
# Standard Error
# 5 , 000 200 ≈ 353.55 Standard Error= 200​
#
# 5,000​≈353.55
#
# Step 3: Calculate the margin of error
# Margin of Error
# 1.96 × 353.55 ≈ 692.97 Margin of Error=1.96×353.55≈692.97
#
# Step 4: Calculate the confidence interval
# Confidence Interval
# 50 , 000 ± 692.97 Confidence Interval=50,000±692.97 So, the 95% confidence interval is approximately [49,307.03, 50,692.97].
#
# This means that you are 95% confident that the true population mean income lies between
# 50,692.97.
#
# 16.How is Bayes' Theorem used in statistics, and what is its significance?
#
# Bayes' Theorem in Statistics
#
# Bayes' Theorem is a fundamental concept in probability theory and statistics that describes how to update the probability of a hypothesis (or event) based on new evidence. It provides a way to revise our beliefs about the likelihood of an event, given prior knowledge and observed data.
#
# In mathematical terms, Bayes' Theorem is:
#
# 𝑃 ( 𝐻 ∣ 𝐸 )
# 𝑃 ( 𝐸 ∣ 𝐻 ) × 𝑃 ( 𝐻 ) 𝑃 ( 𝐸 ) P(H∣E)= P(E) P(E∣H)×P(H)​
#
# Where:
#
# 𝑃 ( 𝐻 ∣ 𝐸 ) P(H∣E) is the posterior probability, the probability of the hypothesis 𝐻 H being true given the evidence 𝐸 E. 𝑃 ( 𝐸 ∣ 𝐻 )
# P(E∣H) is the likelihood, the probability of observing the evidence 𝐸 E given that the hypothesis 𝐻 H is true.
# 𝑃 ( 𝐻 ) P(H) is the prior probability, the initial probability of the hypothesis 𝐻 H before seeing the evidence 𝐸 E.
# 𝑃 ( 𝐸 ) P(E) is the marginal likelihood or evidence, the total probability of observing the evidence 𝐸 E, which can be computed as: 𝑃 ( 𝐸 )
# ∑ 𝐻 𝑃 ( 𝐸 ∣ 𝐻 ) × 𝑃 ( 𝐻 ) P(E)= H ∑​P(E∣H)×P(H)
# How Bayes' Theorem Works
#
# Bayes' Theorem allows you to update your beliefs about a hypothesis or event as new evidence or data becomes available. Here’s how it works in the context of statistics:
#
# Prior probability ( 𝑃 ( 𝐻 ) P(H)): Before observing new data, we have a prior belief or assumption about the probability of a hypothesis being true.
#
# Likelihood ( 𝑃 ( 𝐸 ∣ 𝐻 ) P(E∣H)): After observing new data, we evaluate how likely it is to observe this evidence given the hypothesis.
#
# Posterior probability ( 𝑃 ( 𝐻 ∣ 𝐸 ) P(H∣E)): Using Bayes' Theorem, we combine our prior belief with the likelihood of the evidence to calculate the updated probability (posterior) of the hypothesis.
#
# Significance of Bayes' Theorem
#
# Bayes' Theorem is extremely significant for several reasons:
#
# Updating Beliefs with New Data
# Bayesian updating allows you to continuously refine your knowledge as new data comes in. It is especially useful in situations where we start with an initial assumption (prior probability) and want to adjust it as more evidence becomes available.
# Real-World Applications
# Medical Diagnosis: In healthcare, Bayes' Theorem is used to update the probability of a patient having a disease, based on new test results. For example, if a patient tests positive for a disease, Bayes' Theorem can help calculate the probability that they actually have the disease, considering factors like the test accuracy and prevalence of the disease.
#
# Spam Filtering: Bayes' Theorem is the foundation of Bayesian spam filters, which classify emails as either spam or non-spam based on prior probabilities of spam emails and the likelihood of certain words appearing in them.
#
# Machine Learning: Bayesian methods are widely used in machine learning and data science for updating predictive models based on new data. Bayesian networks and Markov chain Monte Carlo (MCMC) methods rely on Bayes' Theorem for probabilistic inference.
#
# Handling Uncertainty
# In many real-world problems, there is inherent uncertainty. Bayes' Theorem helps model and quantify this uncertainty, allowing for more flexible decision-making based on partial or incomplete information.
# Incorporating Prior Knowledge
# The prior in Bayes' Theorem allows you to incorporate previous knowledge or expert opinion into the analysis. This is especially important when data is scarce or when the sample size is small.
# Example of Using Bayes' Theorem
#
# Let's consider a medical diagnosis example to demonstrate how Bayes' Theorem works in practice.
#
# Scenario:
#
# A certain disease has a 1% prevalence in the general population (i.e., 𝑃 ( 𝐻 )
# 0.01 P(H)=0.01).
#
# A test for the disease has a 95% true positive rate (i.e., if a person has the disease, the test will return a positive result with probability 𝑃 ( 𝐸 ∣ 𝐻 )
# 0.95 P(E∣H)=0.95).
#
# The test also has a 5% false positive rate (i.e., if a person does not have the disease, the test will still return a positive result 5% of the time, 𝑃 ( 𝐸 ∣ ¬ 𝐻 )
# 0.05 P(E∣¬H)=0.05).
#
# Now, a patient gets a positive test result, and we want to know the probability that they actually have the disease (i.e., the posterior probability 𝑃 ( 𝐻 ∣ 𝐸 ) P(H∣E)).
#
# Solution using Bayes' Theorem:
#
# We know:
#
# Prior probability: 𝑃 ( 𝐻 )
# 0.01 P(H)=0.01 (1% chance the patient has the disease).
#
# Likelihood: 𝑃 ( 𝐸 ∣ 𝐻 )
# 0.95 P(E∣H)=0.95 (the probability of a positive test result if the patient has the disease).
#
# False positive rate: 𝑃 ( 𝐸 ∣ ¬ 𝐻 )
# 0.05 P(E∣¬H)=0.05 (the probability of a positive test result when the patient does not have the disease). First, calculate the total probability of observing the positive test result, 𝑃 ( 𝐸 ) P(E), which is the sum of the probabilities of the test being positive for both diseased and non-diseased individuals:
#
# 𝑃 ( 𝐸 )
# 𝑃 ( 𝐸 ∣ 𝐻 ) × 𝑃 ( 𝐻 ) + 𝑃 ( 𝐸 ∣ ¬ 𝐻 ) × 𝑃 ( ¬ 𝐻 ) P(E)=P(E∣H)×P(H)+P(E∣¬H)×P(¬H) 𝑃 ( 𝐸 )
# ( 0.95 × 0.01 ) + ( 0.05 × 0.99 )
# 0.0095 + 0.0495
# 0.059 P(E)=(0.95×0.01)+(0.05×0.99)=0.0095+0.0495=0.059 Now, apply Bayes' Theorem to find the posterior probability:
#
# 𝑃 ( 𝐻 ∣ 𝐸 )
# 𝑃 ( 𝐸 ∣ 𝐻 ) × 𝑃 ( 𝐻 ) 𝑃 ( 𝐸 )
# 0.95 × 0.01 0.059 ≈ 0.161 P(H∣E)= P(E) P(E∣H)×P(H)​
# 0.059 0.95×0.01​≈0.161 Interpretation: Given that the test result is positive, the probability that the patient actually has the disease is about 16.1%. Despite the test having a high true positive rate, the relatively low prevalence of the disease and the false positive rate reduce the likelihood that the patient truly has the disease.
#
# 17.What is the Chi-square distribution, and when is it used?
#
# What is the Chi-Square Distribution?
#
# The Chi-square distribution is a probability distribution that arises in statistics when we are dealing with variance and frequencies. It is a continuous probability distribution that is used primarily for tests of goodness of fit, independence, and homogeneity.
#
# The Chi-square distribution is defined as the distribution of a sum of the squares of independent standard normal random variables. Specifically, if 𝑍 1 , 𝑍 2 , … , 𝑍 𝑘 Z 1​,Z 2​,…,Z k​are independent standard normal variables (i.e., each has a mean of 0 and a variance of 1), then the random variable:
#
# 𝑋 2
# 𝑍 1 2 + 𝑍 2 2 + ⋯ + 𝑍 𝑘 2 X 2 =Z 1 2​+Z 2 2​+⋯+Z k 2​
#
# follows a Chi-square distribution with 𝑘 k degrees of freedom.
#
# Key Properties of the Chi-Square Distribution:
#
# Shape: The Chi-square distribution is skewed to the right, particularly for smaller degrees of freedom. As the degrees of freedom increase, it becomes more symmetric and approaches a normal distribution.
#
# Degrees of Freedom: The shape of the Chi-square distribution depends on the number of degrees of freedom (df), which typically represents the number of independent variables or observations in the analysis.
#
# Range: The Chi-square distribution is always non-negative (i.e., 𝑋 2 ≥ 0 X 2 ≥0) because it is the sum of squared terms.
#
# Mean and Variance:
#
# Mean of a Chi-square distribution with 𝑘 k degrees of freedom: 𝜇
# 𝑘 μ=k
#
# Variance of a Chi-square distribution with 𝑘 k degrees of freedom: 𝜎 2
# 2 𝑘 σ 2 =2k
#
# When is the Chi-Square Distribution Used?
#
# The Chi-square distribution is commonly used in inferential statistics for testing hypotheses about categorical data. It is primarily used in the following contexts:
#
# Chi-Square Goodness of Fit Test
# This test is used to determine if a sample data matches a theoretical distribution.
#
# Example: You might use the Chi-square goodness of fit test to see if the distribution of colors in a bag of M&Ms follows a uniform distribution, as expected by the manufacturer.
#
# Hypothesis:
#
# Null hypothesis: The observed data follows the expected distribution.
#
# Alternative hypothesis: The observed data does not follow the expected distribution.
#
# The test statistic is calculated as:
#
# 𝜒 2
# ∑ ( 𝑂 𝑖 − 𝐸 𝑖 ) 2 𝐸 𝑖 χ 2 =∑ E i​
#
# (O i​−E i​) 2
#
# ​
#
# Where:
#
# 𝑂 𝑖 O i​is the observed frequency for category 𝑖 i,
#
# 𝐸 𝑖 E i​is the expected frequency for category 𝑖 i.
#
# The sum runs over all categories.
#
# 2. Chi-Square Test of Independence
#
# This test is used to determine if two categorical variables are independent of each other.
#
# Example: You might want to test if there is an association between gender (male/female) and whether people prefer coffee or tea.
#
# Hypothesis:
#
# Null hypothesis: The two categorical variables are independent (no association).
#
# Alternative hypothesis: The two categorical variables are dependent (there is an association).
#
# The Chi-square statistic for this test is also calculated using the observed and expected frequencies in a contingency table:
#
# 𝜒 2
# ∑ ( 𝑂 𝑖 𝑗 − 𝐸 𝑖 𝑗 ) 2 𝐸 𝑖 𝑗 χ 2 =∑ E ij​
#
# (O ij​−E ij​) 2
#
# ​
#
# Where:
#
# 𝑂 𝑖 𝑗 O ij​is the observed frequency in the 𝑖 i-th row and 𝑗 j-th column of the table.
#
# 𝐸 𝑖 𝑗 E ij​is the expected frequency in the 𝑖 i-th row and 𝑗 j-th column under the assumption of independence.
#
# 3. Chi-Square Test for Homogeneity
#
# This test is used to determine if different populations have the same distribution of a categorical variable.
#
# Example: You might use this test to compare the preferences of coffee vs. tea in different age groups (e.g., under 30, 30-50, and over 50).
#
# Hypothesis:
#
# Null hypothesis: The distributions of the categorical variable are the same across the populations.
#
# Alternative hypothesis: The distributions of the categorical variable differ across the populations.
#
# 18.What is the Chi-square goodness of fit test, and how is it applied?
#
# Chi-Square Goodness of Fit Test
#
# The Chi-square goodness of fit test is a statistical test used to determine how well an observed frequency distribution matches an expected distribution. In other words, it assesses whether the observed data fit a specific theoretical distribution (e.g., a uniform distribution, a normal distribution, or any other known distribution).
#
# It is commonly used to test hypotheses about the distribution of categorical data. The test compares the observed frequencies in each category to the expected frequencies under the assumption that a specific distribution holds.
#
# Key Components of the Test:
#
# 1.Observed Frequencies ( 𝑂 𝑖 O i​): The actual counts of observations in each category from your sample data.
#
# 2.Expected Frequencies ( 𝐸 𝑖 E i​): The counts you would expect in each category if the data followed the theoretical distribution. These are usually derived from probabilities or proportions specified in the null hypothesis.
#
# 3.Degrees of Freedom (df): The degrees of freedom for a Chi-square goodness of fit test are calculated as:
#
# 𝑑 𝑓
# 𝑘 − 1 df=k−1 Where 𝑘 k is the number of categories being analyzed.
#
# 4.Test Statistic: The Chi-square statistic is calculated using the following formula:
#
# 𝜒 2
# ∑ ( 𝑂 𝑖 − 𝐸 𝑖 ) 2 𝐸 𝑖 χ 2 =∑ E i​
#
# (O i​−E i​) 2
#
# ​
#
# Where:
#
# 𝑂 𝑖 O i​is the observed frequency in the 𝑖 i-th category,
# 𝐸 𝑖 E i​is the expected frequency in the 𝑖 i-th category,
# The sum runs over all categories.
# 5.Significance Level ( 𝛼 α): The significance level (e.g., 𝛼
# 0.05 α=0.05) is chosen to determine whether the result is statistically significant.
#
# 6.Critical Value: The critical value is obtained from the Chi-square distribution table for a given significance level ( 𝛼 α) and degrees of freedom. If the test statistic exceeds the critical value, you reject the null hypothesis.
#
# Steps in Conducting a Chi-Square Goodness of Fit Test
#
# 1.State the Hypotheses:
#
# Null Hypothesis ( 𝐻 0 H 0​): The data follows the specified distribution.
#
# Alternative Hypothesis ( 𝐻 1 H 1​): The data does not follow the specified distribution.
#
# 2.Calculate the Expected Frequencies: Based on the null hypothesis, calculate the expected frequencies for each category. For example, if you assume a uniform distribution and you have 4 categories, each category should have an expected frequency of 𝐸 𝑖
# 1 4 E i​
# 4 1​of the total sample size.
#
# 3.Calculate the Chi-Square Statistic: Using the observed and expected frequencies, calculate the Chi-square statistic using the formula:
#
# 𝜒 2
# ∑ ( 𝑂 𝑖 − 𝐸 𝑖 ) 2 𝐸 𝑖 χ 2 =∑ E i​
#
# (O i​−E i​) 2
#
# ​
#
# Where:
#
# 𝑂 𝑖 O i​is the observed frequency in each category,
# 𝐸 𝑖 E i​is the expected frequency in each category.
# 4.Determine the Degrees of Freedom: The degrees of freedom for the test are 𝑑 𝑓
# 𝑘 − 1 df=k−1, where 𝑘 k is the number of categories.
#
# 5.Compare the Test Statistic to the Critical Value: Use the Chi-square distribution table to find the critical value for the given degrees of freedom and significance level ( 𝛼 α).
#
# If the Chi-square statistic is greater than the critical value, you reject the null hypothesis.
#
# If the Chi-square statistic is less than or equal to the critical value, you fail to reject the null hypothesis.
#
# 19.What is the F-distribution, and when is it used in hypothesis testing?
#
# The F-distribution is a continuous probability distribution that arises frequently in statistics, particularly in hypothesis testing involving variance ratios. It is defined by two degrees of freedom: 𝑑 1 d 1​(numerator degrees of freedom) and 𝑑 2 d 2​(denominator degrees of freedom). The F-distribution is positively skewed and only takes non-negative values.
#
# When is the F-Distribution Used in Hypothesis Testing?
#
# The F-distribution is primarily used in hypothesis tests that compare variances or assess the significance of models in regression. Common applications include:
#
# 1.Analysis of Variance (ANOVA)
#
# Used to compare the means of multiple groups by analyzing variance.
# The test statistic follows an F-distribution under the null hypothesis.
# 2.Regression Analysis (Overall Model Significance Test)
#
# Used to test whether at least one predictor variable in a regression model significantly contributes to explaining the variation in the dependent variable.
# The test compares the variance explained by the model to the variance of the residuals.
# 3.Equality of Two Variances (F-Test for Variance Ratio)
#
# Used to test if two populations have the same variance.
#
# The test statistic is the ratio of two sample variances.
#
# 20.What is an ANOVA test, and what are its assumptions?
#
# What is an ANOVA Test?
#
# ANOVA (Analysis of Variance) is a statistical method used to compare the means of three or more groups to determine if there is a statistically significant difference among them. It extends the t-test, which is used for comparing two means, to multiple groups.
#
# Types of ANOVA:
#
# 1.One-Way ANOVA – Compares means of multiple groups based on one independent variable (factor).
#
# 2.Two-Way ANOVA – Examines the effect of two independent variables on a dependent variable and their interaction.
#
# 3.Repeated Measures ANOVA – Used when the same subjects are tested under multiple conditions or over time.
#
# ANOVA Hypotheses:
#
# Null Hypothesis (H₀): All group means are equal.
# Alternative Hypothesis (H₁): At least one group mean is different.
# The test statistic follows an F-distribution and is calculated as:
#
# 𝐹
# Between-group variance Within-group variance F= Within-group variance Between-group variance​
#
# If the F-statistic is significantly large, we reject 𝐻 0 H 0​in favor of 𝐻 1 H 1​.
#
# Assumptions of ANOVA:
#
# For ANOVA results to be valid, the following assumptions must hold:
#
# 1.Independence – Observations should be independent within and across groups.
#
# 2.Normality – The dependent variable should be approximately normally distributed within each group (especially important for small samples).
#
# 3.Homogeneity of Variance (Homoscedasticity) – Variances of different groups should be equal (tested using Levene’s Test or Bartlett’s Test).
#
# If assumptions are violated, non-parametric tests like the Kruskal-Wallis test (for one-way ANOVA) may be used instead.
#
# 21.What are the different types of ANOVA tests?
#
# Different Types of ANOVA Tests
#
# ANOVA (Analysis of Variance) is categorized based on the number of independent variables (factors) and whether measurements are repeated. The main types include:
#
# 1. One-Way ANOVA
#
# Purpose: Compares the means of three or more independent groups based on a single factor.
#
# Example: Testing if three different diets lead to different weight loss outcomes.
#
# Assumptions: Normality, independence, and homogeneity of variances.
#
# 2. Two-Way ANOVA
#
# Purpose: Examines the effect of two independent factors on a dependent variable, including interaction effects.
#
# Example: Analyzing the impact of diet type and exercise level on weight loss.
#
# Variants:
#
# Without Interaction: Tests main effects of both factors separately.
#
# With Interaction: Tests if the combination of two factors influences the outcome differently.
#
# 3. Repeated Measures ANOVA
#
# Purpose: Used when the same subjects are measured multiple times under different conditions.
#
# Example: Testing how reaction times change before, during, and after caffeine consumption in the same individuals.
#
# Assumptions: Normality, sphericity (variance of differences is equal).
#
# 4. Two-Way Repeated Measures ANOVA
#
# Purpose: Tests the effects of two within-subject factors.
#
# Example: Measuring the impact of diet (Factor 1) and exercise (Factor 2) on weight loss in the same participants over time.
#
# 5. Mixed-Design ANOVA (Split-Plot ANOVA)
#
# Purpose: Combines both within-subject (repeated measures) and between-subject factors.
#
# Example: Studying the effect of a drug (placebo vs. real drug) over multiple time points in different patient groups.
#
# 6. MANOVA (Multivariate Analysis of Variance)
#
# Purpose: Used when there are multiple dependent variables.
#
# Example: Testing if teaching methods influence both math and reading scores.
#
# Advantage: Considers correlations between dependent variables.
#
# 7. ANCOVA (Analysis of Covariance)
#
# Purpose: Similar to ANOVA but includes covariates (continuous control variables) to adjust for confounding effects.
#
# Example: Studying exam performance based on teaching methods while controlling for prior knowledge (covariate: pre-test scores).
#
# 8. MANCOVA (Multivariate Analysis of Covariance)
#
# Purpose: Like MANOVA but adjusts for covariates.
#
# Example: Comparing teaching methods on math and reading scores, while controlling for IQ levels.
#
# 22.What is the F-test, and how does it relate to hypothesis testing?
#
# What is the F-Test?
#
# The F-test is a statistical test used to compare variances, test model significance, or analyze variance in different hypothesis testing scenarios. It is based on the F-distribution, which is a ratio of two independent chi-square distributed variables divided by their degrees of freedom.
#
# Formula for the F-Statistic
#
# 𝐹
# Variance of Group 1 Variance of Group 2 F= Variance of Group 2 Variance of Group 1​
#
# or
#
# 𝐹
# Explained Variance Unexplained Variance F= Unexplained Variance Explained Variance​
#
# depending on the test type.
#
# How Does the F-Test Relate to Hypothesis Testing?
#
# The F-test is commonly used in the following hypothesis tests:
#
# 1. Variance Comparison (Two-Sample F-Test)
#
# Purpose: Tests if two populations have equal variances.
#
# Hypotheses: 𝐻 0 H 0​: 𝜎 1 2
# 𝜎 2 2 σ 1 2​=σ 2 2​(Equal variances) 𝐻 1 H 1​: 𝜎 1 2 ≠ 𝜎 2 2 σ 1 2​
#
#  =σ 2 2​(Unequal variances)
#
# Application: Checking the assumption of equal variances before performing a t-test.
# 2. ANOVA (Analysis of Variance)
#
# Purpose: Compares means of three or more groups by analyzing variance.
#
# Hypotheses:
#
# 𝐻 0 H 0​: All group means are equal.
#
# 𝐻 1 H 1​: At least one group mean is different.
#
# F-Statistic: 𝐹
# Between-group variance Within-group variance F= Within-group variance Between-group variance​
#
# Application: Used in One-Way and Two-Way ANOVA to determine if means differ significantly.
#
# 3. Regression Model Significance (F-Test in Regression)
#
# Purpose: Tests if a regression model significantly explains the variation in the dependent variable.
#
# Hypotheses:
#
# 𝐻 0 H 0​: The regression model has no explanatory power (all coefficients = 0).
#
# 𝐻 1 H 1​: At least one independent variable contributes significantly.
#
# F-Statistic: 𝐹
# Regression Mean Square Residual Mean Square F= Residual Mean Square Regression Mean Square​
#
# Application: Used to check the overall significance of a multiple regression model.
#
# Key Properties of the F-Test
#
# Always non-negative ( 𝐹 ≥ 0 F≥0).
#
# Positively skewed, especially for small sample sizes.
#
# Degrees of freedom depend on the test type (e.g., ANOVA uses 𝑑 1
# 𝑘 − 1 d 1​=k−1, 𝑑 2
# 𝑁 − 𝑘 d 2​=N−k).
#
# One-tailed test (typically tests for variance differences in one direction).

# %%
#Practical
#1.Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results?


import numpy as np
import scipy.stats as stats

def z_test(sample, pop_mean, pop_std, alpha=0.05, alternative="two-sided"):
    """
    Perform a Z-test for comparing a sample mean to a known population mean.

    Parameters:
    sample (list or array): Sample data
    pop_mean (float): Population mean
    pop_std (float): Population standard deviation (known)
    alpha (float): Significance level (default is 0.05)
    alternative (str): "two-sided", "greater", or "less"

    Returns:
    Z-score, p-value, and interpretation of the results
    """

    # Sample statistics
    sample_mean = np.mean(sample)
    sample_size = len(sample)

    # Compute Z-score
    z_score = (sample_mean - pop_mean) / (pop_std / np.sqrt(sample_size))

    # Compute p-value based on test type
    if alternative == "two-sided":
        p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))
    elif alternative == "greater":
        p_value = 1 - stats.norm.cdf(z_score)
    elif alternative == "less":
        p_value = stats.norm.cdf(z_score)
    else:
        raise ValueError("Invalid alternative hypothesis. Choose 'two-sided', 'greater', or 'less'.")

    # Interpretation
    result = "Reject H₀" if p_value < alpha else "Fail to reject H₀"

    return {
        "Z-score": round(z_score, 4),
        "p-value": round(p_value, 4),
        "Conclusion": result
    }

# Example Usage
sample_data = [72, 74, 71, 69, 73, 75, 70, 72, 74, 71]  # Sample data
population_mean = 70  # Known population mean
population_std = 3  # Known population standard deviation

# Perform Z-test (two-tailed test)
result = z_test(sample_data, population_mean, population_std, alpha=0.05, alternative="two-sided")

# Display results
print("Z-Test Results:")
print(result)
# Out:
# Z-Test Results:
# {'Z-score': 2.2136, 'p-value': 0.0269, 'Conclusion': 'Reject H₀'}

# %%
#2.Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python?


import numpy as np
import scipy.stats as stats

# Step 1: Simulate random sample data (normally distributed)
np.random.seed(42)  # For reproducibility
sample_size = 30  # Change for different sample sizes
pop_mean = 100  # Known population mean
pop_std = 15  # Known population standard deviation

# Generate random sample data
sample_data = np.random.normal(loc=pop_mean, scale=pop_std, size=sample_size)

# Step 2: Perform Hypothesis Testing (Z-test or T-test based on known/unknown population std)
def perform_test(sample, pop_mean, pop_std=None, alpha=0.05, test_type="z-test", alternative="two-sided"):
    sample_mean = np.mean(sample)
    sample_size = len(sample)

    if test_type == "z-test" and pop_std is not None:
        # Z-test (when population std is known)
        standard_error = pop_std / np.sqrt(sample_size)
        test_stat = (sample_mean - pop_mean) / standard_error
        distribution = stats.norm  # Normal distribution

    elif test_type == "t-test" or pop_std is None:
        # T-test (when population std is unknown)
        test_stat, p_value = stats.ttest_1samp(sample, pop_mean)
        return {"Test Type": "T-test", "Test Statistic": round(test_stat, 4), "p-value": round(p_value, 4),
                "Conclusion": "Reject H₀" if p_value < alpha else "Fail to reject H₀"}

    # Compute p-value for Z-test
    if alternative == "two-sided":
        p_value = 2 * (1 - distribution.cdf(abs(test_stat)))
    elif alternative == "greater":
        p_value = 1 - distribution.cdf(test_stat)
    elif alternative == "less":
        p_value = distribution.cdf(test_stat)
    else:
        raise ValueError("Invalid alternative hypothesis. Choose 'two-sided', 'greater', or 'less'.")

    return {"Test Type": "Z-test", "Test Statistic": round(test_stat, 4), "p-value": round(p_value, 4),
            "Conclusion": "Reject H₀" if p_value < alpha else "Fail to reject H₀"}

# Step 3: Run the test (Choose Z-test if population std is known, otherwise T-test)
result = perform_test(sample_data, pop_mean, pop_std, alpha=0.05, test_type="z-test")

# Step 4: Display results
print("Hypothesis Test Results:")
print(result)
# Out:
# Hypothesis Test Results:
# {'Test Type': 'Z-test', 'Test Statistic': -1.0305, 'p-value': 0.3028, 'Conclusion': 'Fail to reject H₀'}

# %%
#3.Implement a one-sample Z-test using Python to compare the sample mean with the population mean?


import numpy as np
import scipy.stats as stats

def one_sample_z_test(sample, pop_mean, pop_std, alpha=0.05, alternative="two-sided"):
    """
    Performs a one-sample Z-test.

    Parameters:
    - sample: list or numpy array, sample data
    - pop_mean: float, population mean
    - pop_std: float, known population standard deviation
    - alpha: float, significance level (default 0.05)
    - alternative: str, "two-sided", "greater", or "less"

    Returns:
    - Z-score, p-value, and conclusion of the hypothesis test
    """

    # Calculate sample statistics
    sample_mean = np.mean(sample)
    sample_size = len(sample)

    # Compute Z-score
    standard_error = pop_std / np.sqrt(sample_size)
    z_score = (sample_mean - pop_mean) / standard_error

    # Compute p-value based on alternative hypothesis
    if alternative == "two-sided":
        p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))
    elif alternative == "greater":
        p_value = 1 - stats.norm.cdf(z_score)
    elif alternative == "less":
        p_value = stats.norm.cdf(z_score)
    else:
        raise ValueError("Invalid alternative hypothesis. Choose 'two-sided', 'greater', or 'less'.")

    # Conclusion based on significance level
    conclusion = "Reject H₀" if p_value < alpha else "Fail to reject H₀"

    return {
        "Z-score": round(z_score, 4),
        "p-value": round(p_value, 4),
        "Conclusion": conclusion
    }

# Example Usage
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=100, scale=15, size=30)  # Simulating sample data

population_mean = 100  # Population mean
population_std = 15  # Known population standard deviation

# Perform One-Sample Z-Test
result = one_sample_z_test(sample_data, population_mean, population_std, alpha=0.05, alternative="two-sided")

# Print the result
print("One-Sample Z-Test Results:")
print(result)
# Out:
# One-Sample Z-Test Results:
# {'Z-score': -1.0305, 'p-value': 0.3028, 'Conclusion': 'Fail to reject H₀'}

# %%
#4.Perform a two-tailed Z-test using Python and visualize the decision region on a plot?


import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def two_tailed_z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Performs a two-tailed Z-test.

    Parameters:
    - sample: list or numpy array, sample data
    - pop_mean: float, population mean
    - pop_std: float, known population standard deviation
    - alpha: float, significance level (default 0.05)

    Returns:
    - Z-score, p-value, and conclusion of the hypothesis test
    """

    # Calculate sample statistics
    sample_mean = np.mean(sample)
    sample_size = len(sample)

    # Compute Z-score
    standard_error = pop_std / np.sqrt(sample_size)
    z_score = (sample_mean - pop_mean) / standard_error

    # Compute p-value (two-tailed)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Critical value for two-tailed test
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Conclusion
    conclusion = "Reject H₀" if abs(z_score) > z_critical else "Fail to reject H₀"

    # Visualization
    visualize_z_test(z_score, z_critical, alpha)

    return {
        "Z-score": round(z_score, 4),
        "p-value": round(p_value, 4),
        "Critical Value": round(z_critical, 4),
        "Conclusion": conclusion
    }

def visualize_z_test(z_score, z_critical, alpha):
    """
    Visualizes the decision region for a two-tailed Z-test.
    """

    x = np.linspace(-4, 4, 1000)
    y = stats.norm.pdf(x, 0, 1)  # Standard normal distribution

    plt.figure(figsize=(10, 5))
    plt.plot(x, y, label="Standard Normal Distribution", color="black")

    # Shade rejection regions
    plt.fill_between(x, y, where=(x < -z_critical) | (x > z_critical), color='red', alpha=0.3, label="Rejection Region")
    plt.fill_between(x, y, where=(x >= -z_critical) & (x <= z_critical), color='green', alpha=0.3, label="Acceptance Region")

    # Plot critical values
    plt.axvline(-z_critical, linestyle="--", color="red", label=f"Critical Value (-{z_critical:.2f})")
    plt.axvline(z_critical, linestyle="--", color="red", label=f"Critical Value ({z_critical:.2f})")

    # Plot test statistic
    plt.axvline(z_score, linestyle="--", color="blue", label=f"Test Statistic (Z = {z_score:.2f})")

    # Labels and legend
    plt.title("Two-Tailed Z-Test Decision Region")
    plt.xlabel("Z-score")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.show()

# Example Usage
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=102, scale=15, size=30)  # Simulating sample data

population_mean = 100  # Population mean
population_std = 15  # Known population standard deviation

# Perform Two-Tailed Z-Test
result = two_tailed_z_test(sample_data, population_mean, population_std, alpha=0.05)

# Print the result
print("Two-Tailed Z-Test Results:")
print(result)
# Out:
# Two-Tailed Z-Test Results:
# {'Z-score': -0.3002, 'p-value': 0.764, 'Critical Value': 1.96, 'Conclusion': 'Fail to reject H₀'}

# %%
#5.Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing?


import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def visualize_type1_type2_errors(pop_mean, pop_std, sample_size, effect_size, alpha=0.05):
    """
    Plots Type 1 (α) and Type 2 (β) errors for a hypothesis test.

    Parameters:
    - pop_mean: float, true population mean under H0
    - pop_std: float, population standard deviation
    - sample_size: int, number of observations
    - effect_size: float, difference between H0 mean and true mean under H1
    - alpha: float, significance level (default 0.05)
    """

    # Compute standard error
    standard_error = pop_std / np.sqrt(sample_size)

    # Define null and alternative means
    h0_mean = pop_mean
    h1_mean = pop_mean + effect_size  # Mean under H1

    # Compute critical value for given alpha (two-tailed test)
    z_critical = stats.norm.ppf(1 - alpha / 2)
    critical_value = h0_mean + z_critical * standard_error

    # Define x values for distribution curves
    x = np.linspace(h0_mean - 4 * standard_error, h1_mean + 4 * standard_error, 1000)

    # Compute probability density functions
    h0_pdf = stats.norm.pdf(x, h0_mean, standard_error)  # H0 distribution
    h1_pdf = stats.norm.pdf(x, h1_mean, standard_error)  # H1 distribution

    plt.figure(figsize=(10, 5))

    # Plot distributions
    plt.plot(x, h0_pdf, label="H₀ Distribution (Null Hypothesis)", color="blue")
    plt.plot(x, h1_pdf, label="H₁ Distribution (Alternative Hypothesis)", color="green")

    # Shade Type 1 Error (α) - Rejection region under H0
    plt.fill_between(x, h0_pdf, where=(x >= critical_value), color="red", alpha=0.3, label="Type 1 Error (α)")

    # Shade Type 2 Error (β) - Acceptance region under H1
    beta = stats.norm.cdf(critical_value, h1_mean, standard_error)
    plt.fill_between(x, h1_pdf, where=(x < critical_value), color="orange", alpha=0.3, label=f"Type 2 Error (β ≈ {beta:.3f})")

    # Plot critical value
    plt.axvline(critical_value, color="red", linestyle="--", label=f"Critical Value ({critical_value:.2f})")

    # Labels and legend
    plt.title("Type 1 (α) and Type 2 (β) Errors in Hypothesis Testing")
    plt.xlabel("Sample Mean")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.show()

# Example Usage
visualize_type1_type2_errors(pop_mean=100, pop_std=15, sample_size=30, effect_size=5, alpha=0.05)

# %%
#6.Write a Python program to perform an independent T-test and interpret the results?


import numpy as np
import scipy.stats as stats

def independent_t_test(sample1, sample2, alpha=0.05):
    """
    Performs an independent (two-sample) T-test.

    Parameters:
    - sample1: list or numpy array, data for group 1
    - sample2: list or numpy array, data for group 2
    - alpha: float, significance level (default 0.05)

    Returns:
    - T-statistic, p-value, and conclusion of the hypothesis test
    """

    # Check for equal variances using Levene’s test
    levene_stat, levene_p = stats.levene(sample1, sample2)
    equal_var = levene_p > alpha  # Assume equal variance if p > alpha

    # Perform independent T-test
    t_stat, p_value = stats.ttest_ind(sample1, sample2, equal_var=equal_var)

    # Conclusion
    conclusion = "Reject H₀" if p_value < alpha else "Fail to reject H₀"

    return {
        "T-statistic": round(t_stat, 4),
        "p-value": round(p_value, 4),
        "Equal Variance Assumed": equal_var,
        "Levene’s Test p-value": round(levene_p, 4),
        "Conclusion": conclusion
    }

# Example Usage
np.random.seed(42)  # For reproducibility
group1 = np.random.normal(loc=100, scale=15, size=30)  # Simulated group 1 data
group2 = np.random.normal(loc=105, scale=15, size=30)  # Simulated group 2 data

# Perform Independent T-Test
result = independent_t_test(group1, group2, alpha=0.05)

# Print the result
print("Independent T-Test Results:")
print(result)
# Out:
# Independent T-Test Results:
# {'T-statistic': -1.6932, 'p-value': 0.0958, 'Equal Variance Assumed': True, 'Levene’s Test p-value': 0.6223, 'Conclusion': 'Fail to reject H₀'}

# %%
#7.Perform a paired sample T-test using Python and visualize the comparison results?


import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

def paired_t_test(before, after, alpha=0.05):
    """
    Performs a paired sample T-test.

    Parameters:
    - before: list or numpy array, data before treatment/condition
    - after: list or numpy array, data after treatment/condition
    - alpha: float, significance level (default 0.05)

    Returns:
    - T-statistic, p-value, and conclusion of the hypothesis test
    """

    # Calculate paired differences
    differences = np.array(after) - np.array(before)

    # Perform paired T-test
    t_stat, p_value = stats.ttest_rel(before, after)

    # Conclusion
    conclusion = "Reject H₀" if p_value < alpha else "Fail to reject H₀"

    # Visualization
    visualize_paired_t_test(before, after, differences)

    return {
        "T-statistic": round(t_stat, 4),
        "p-value": round(p_value, 4),
        "Mean Difference": round(np.mean(differences), 4),
        "Conclusion": conclusion
    }

def visualize_paired_t_test(before, after, differences):
    """
    Visualizes the paired sample data before and after treatment.
    """
    plt.figure(figsize=(12, 5))

    # 1. Boxplot of Before vs. After
    plt.subplot(1, 2, 1)
    sns.boxplot(data=[before, after], palette=["blue", "green"])
    plt.xticks([0, 1], ["Before", "After"])
    plt.title("Boxplot of Before vs. After")

    # 2. Scatter Plot of Before vs. After
    plt.subplot(1, 2, 2)
    plt.scatter(before, after, color="purple", alpha=0.7, label="Data Points")
    plt.plot([min(before), max(before)], [min(before), max(before)], 'r--', label="y=x Line (No Change)")
    plt.xlabel("Before")
    plt.ylabel("After")
    plt.title("Before vs. After Scatter Plot")
    plt.legend()

    plt.tight_layout()
    plt.show()

# Example Usage
np.random.seed(42)  # For reproducibility
before_data = np.random.normal(loc=100, scale=10, size=30)  # Simulated "Before" data
after_data = before_data + np.random.normal(loc=2, scale=5, size=30)  # Simulated "After" data with slight improvement

# Perform Paired Sample T-Test
result = paired_t_test(before_data, after_data, alpha=0.05)

# Print the result
print("Paired Sample T-Test Results:")
print(result)
# Out:
# Paired Sample T-Test Results:
# {'T-statistic': -1.6403, 'p-value': 0.1118, 'Mean Difference': 1.3942, 'Conclusion': 'Fail to reject H₀'}

# %%
#8.Simulate data and perform both Z-test and T-test, then compare the results using Python?
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def perform_z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Performs a one-sample Z-test.

    Parameters:
    - sample: numpy array, sample data
    - pop_mean: float, known population mean
    - pop_std: float, known population standard deviation
    - alpha: float, significance level

    Returns:
    - Z-statistic, p-value, and conclusion
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    z_stat = (sample_mean - pop_mean) / standard_error
    p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))  # Two-tailed test

    conclusion = "Reject H₀" if p_value < alpha else "Fail to reject H₀"

    return {"Test": "Z-Test", "Z-statistic": round(z_stat, 4), "p-value": round(p_value, 4), "Conclusion": conclusion}

def perform_t_test(sample, pop_mean, alpha=0.05):
    """
    Performs a one-sample T-test.

    Parameters:
    - sample: numpy array, sample data
    - pop_mean: float, known population mean
    - alpha: float, significance level

    Returns:
    - T-statistic, p-value, and conclusion
    """
    t_stat, p_value = stats.ttest_1samp(sample, pop_mean)
    conclusion = "Reject H₀" if p_value < alpha else "Fail to reject H₀"

    return {"Test": "T-Test", "T-statistic": round(t_stat, 4), "p-value": round(p_value, 4), "Conclusion": conclusion}

def visualize_results(sample, pop_mean):
    """
    Visualizes the sample distribution and population mean.
    """
    plt.figure(figsize=(10, 5))
    sns.histplot(sample, kde=True, color="blue", bins=15, alpha=0.6, label="Sample Distribution")
    plt.axvline(np.mean(sample), color="red", linestyle="--", label="Sample Mean")
    plt.axvline(pop_mean, color="green", linestyle="--", label="Population Mean")
    plt.title("Sample Distribution vs. Population Mean")
    plt.xlabel("Value")
    plt.ylabel("Density")
    plt.legend()
    plt.show()

# Simulate Data
np.random.seed(42)  # For reproducibility
pop_mean = 100  # True population mean
pop_std = 15  # Known population standard deviation
sample_size = 25  # Small sample (to compare T-test)
sample = np.random.normal(loc=pop_mean + 5, scale=pop_std, size=sample_size)  # Shifted sample

# Perform Tests
z_test_result = perform_z_test(sample, pop_mean, pop_std, alpha=0.05)
t_test_result = perform_t_test(sample, pop_mean, alpha=0.05)

# Print Results
print("Z-Test Result:", z_test_result)
print("T-Test Result:", t_test_result)

# Visualization
visualize_results(sample, pop_mean)
# Out:
# Z-Test Result: {'Test': 'Z-Test', 'Z-statistic': 0.8491, 'p-value': 0.3958, 'Conclusion': 'Fail to reject H₀'}
# T-Test Result: {'Test': 'T-Test', 'T-statistic': 0.8877, 'p-value': 0.3835, 'Conclusion': 'Fail to reject H₀'}

# %%
#9.Write a Python function to calculate the confidence interval for a sample mean and explain its significance?


import numpy as np
import scipy.stats as stats

def confidence_interval(sample, confidence=0.95):
    """
    Calculates the confidence interval for the mean of a sample.

    Parameters:
    - sample: list or numpy array, the sample data
    - confidence: float, confidence level (default 0.95)

    Returns:
    - (lower_bound, upper_bound): Tuple containing the confidence interval bounds
    """
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation (unbiased)
    n = len(sample)

    # Select t-distribution or Z-distribution based on sample size
    if n >= 30:
        z_or_t = stats.norm.ppf(1 - (1 - confidence) / 2)  # Z-score for large samples
    else:
        z_or_t = stats.t.ppf(1 - (1 - confidence) / 2, df=n-1)  # t-score for small samples

    margin_of_error = z_or_t * (sample_std / np.sqrt(n))

    lower_bound = round(sample_mean - margin_of_error, 4)
    upper_bound = round(sample_mean + margin_of_error, 4)

    return lower_bound, upper_bound

# Example Usage
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=100, scale=15, size=25)  # Simulated sample

ci = confidence_interval(sample_data, confidence=0.95)
print(f"95% Confidence Interval: {ci}")
# Out:
# 95% Confidence Interval: (91.6247, 103.4701)

# %%
#10.Write a Python program to calculate the margin of error for a given confidence level using sample data?


import numpy as np
import scipy.stats as stats

def margin_of_error(sample, confidence=0.95):
    """
    Calculates the margin of error for a given confidence level using sample data.

    Parameters:
    - sample: list or numpy array, the sample data
    - confidence: float, confidence level (default 0.95)

    Returns:
    - margin_of_error: float, the margin of error
    """
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation (unbiased)
    n = len(sample)

    # Use t-distribution for small samples, Z-distribution for large samples
    if n >= 30:
        z_or_t = stats.norm.ppf(1 - (1 - confidence) / 2)  # Z-score for large samples
    else:
        z_or_t = stats.t.ppf(1 - (1 - confidence) / 2, df=n-1)  # t-score for small samples

    margin_of_error = round(z_or_t * (sample_std / np.sqrt(n)), 4)

    return margin_of_error

# Example Usage
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=100, scale=15, size=25)  # Simulated sample

moe = margin_of_error(sample_data, confidence=0.95)
print(f"95% Margin of Error: {moe}")
# Out:
# 95% Margin of Error: 5.9227

# %%
#11.Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process?


def bayes_theorem(prior, sensitivity, false_positive_rate):
    """
    Implements Bayes' Theorem for a binary classification problem.

    Parameters:
    - prior: float, P(H) - Prior probability of the hypothesis (e.g., having COVID-19).
    - sensitivity: float, P(E | H) - Sensitivity or True Positive Rate.
    - false_positive_rate: float, P(E | ~H) - False Positive Rate.

    Returns:
    - posterior: float, P(H | E) - Updated probability after observing evidence.
    """
    # P(E) = P(E | H) * P(H) + P(E | ~H) * P(~H)
    marginal_likelihood = (sensitivity * prior) + (false_positive_rate * (1 - prior))

    # P(H | E) = (P(E | H) * P(H)) / P(E)
    posterior = (sensitivity * prior) / marginal_likelihood

    return round(posterior, 4)

# Example: COVID-19 Test
prior_covid = 0.01  # 1% of people have COVID
sensitivity_covid = 0.95  # True positive rate
false_positive_covid = 0.05  # False positive rate

posterior_covid = bayes_theorem(prior_covid, sensitivity_covid, false_positive_covid)
print(f"Probability of having COVID-19 after testing positive: {posterior_covid * 100:.2f}%")
# Out:
# Probability of having COVID-19 after testing positive: 16.10%

# %%
#12.Perform a Chi-square test for independence between two categorical variables in Python?


import numpy as np
import pandas as pd
import scipy.stats as stats

# Sample Data: Gender vs. Product Preference (Contingency Table)
data = np.array([[50, 30],  # Male: 50 prefer A, 30 prefer B
                 [20, 40]]) # Female: 20 prefer A, 40 prefer B

# Create a DataFrame for better visualization
df = pd.DataFrame(data, columns=["Product A", "Product B"], index=["Male", "Female"])
print("Contingency Table:\n", df)

# Perform Chi-Square Test for Independence
chi2_stat, p_value, dof, expected = stats.chi2_contingency(data)

# Display Results
print(f"\nChi-Square Statistic: {chi2_stat:.4f}")
print(f"Degrees of Freedom: {dof}")
print(f"P-value: {p_value:.4f}")

# Print Expected Frequencies
expected_df = pd.DataFrame(expected, columns=["Product A", "Product B"], index=["Male", "Female"])
print("\nExpected Frequencies:\n", expected_df)

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("\nReject the null hypothesis (H0): Gender and Product Preference are dependent.")
else:
    print("\nFail to reject the null hypothesis (H0): Gender and Product Preference are independent.")
# Out:
# Contingency Table:
#          Product A  Product B
# Male           50         30
# Female         20         40
#
# Chi-Square Statistic: 10.5292
# Degrees of Freedom: 1
# P-value: 0.0012
#
# Expected Frequencies:
#          Product A  Product B
# Male         40.0       40.0
# Female       30.0       30.0
#
# Reject the null hypothesis (H0): Gender and Product Preference are dependent.

# %%
#13.Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data?


import numpy as np

def calculate_expected_frequencies(observed_data):
    """
    Calculate the expected frequencies for a given contingency table.

    Parameters:
    - observed_data: 2D numpy array or list, observed counts in the contingency table

    Returns:
    - expected_frequencies: 2D numpy array, expected frequencies under the assumption of independence
    """
    # Total number of observations
    total = np.sum(observed_data)

    # Row sums (marginal totals)
    row_totals = np.sum(observed_data, axis=1)

    # Column sums (marginal totals)
    column_totals = np.sum(observed_data, axis=0)

    # Calculate expected frequencies
    expected_frequencies = np.outer(row_totals, column_totals) / total

    return expected_frequencies

# Example: Gender vs. Product Preference (Observed Data)
observed_data = np.array([[50, 30],  # Male: 50 prefer A, 30 prefer B
                          [20, 40]]) # Female: 20 prefer A, 40 prefer B

# Calculate expected frequencies
expected_frequencies = calculate_expected_frequencies(observed_data)

# Display Results
print("Observed Data:\n", observed_data)
print("\nExpected Frequencies:\n", expected_frequencies)
# Out:
# Observed Data:
#  [[50 30]
#  [20 40]]
#
# Expected Frequencies:
#  [[40. 40.]
#  [30. 30.]]

# %%
#14.Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution?
import numpy as np
import scipy.stats as stats

def chi_square_goodness_of_fit(observed_data):
    """
    Perform a Chi-Square Goodness-of-Fit Test with dynamically computed expected values.

    Parameters:
    - observed_data: List or numpy array, observed frequencies

    Returns:
    - chi2_stat: Chi-Square statistic
    - p_value: P-value of the test
    """
    # Calculate expected frequencies dynamically
    total_observed = np.sum(observed_data)
    num_categories = len(observed_data)
    expected_data = np.full(num_categories, total_observed / num_categories)  # Equal expected distribution

    # Perform the Chi-Square Goodness-of-Fit test
    chi2_stat, p_value = stats.chisquare(observed_data, expected_data)

    return chi2_stat, p_value

# Observed frequencies from rolling the die
observed = np.array([12, 10, 15, 8, 18, 7])

# Perform the Chi-Square Goodness-of-Fit Test
chi2_stat, p_value = chi_square_goodness_of_fit(observed)

# Display results
print(f"Chi-Square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("\nReject the null hypothesis: The observed data does not follow the expected distribution.")
else:
    print("\nFail to reject the null hypothesis: The observed data follows the expected distribution.")
# Out:
# Chi-Square Statistic: 7.6571
# P-value: 0.1762
#
# Fail to reject the null hypothesis: The observed data follows the expected distribution.

# %%
#15.Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics?


import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Simulate and visualize the Chi-square distribution for different degrees of freedom (df)

# Define parameters
df_values = [1, 2, 5, 10, 20]  # Different degrees of freedom
x = np.linspace(0, 30, 1000)   # Range of x values (from 0 to 30)

# Create the plot
plt.figure(figsize=(10, 6))

# Plot Chi-square distributions for different degrees of freedom
for df in df_values:
    y = stats.chi2.pdf(x, df)  # Probability density function for Chi-square distribution
    plt.plot(x, y, label=f'df={df}')

# Customize the plot
plt.title('Chi-Square Distribution for Different Degrees of Freedom')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.legend(title='Degrees of Freedom')
plt.grid(True)
plt.show()

# %%
#16.Implement an F-test using Python to compare the variances of two random samples?


import numpy as np
import scipy.stats as stats

def f_test(sample1, sample2):
    """
    Perform the F-test to compare the variances of two independent samples.

    Parameters:
    - sample1: First sample (list or numpy array)
    - sample2: Second sample (list or numpy array)

    Returns:
    - f_stat: F-statistic
    - p_value: p-value for the test
    """
    # Calculate the sample variances
    var1 = np.var(sample1, ddof=1)  # Use ddof=1 for sample variance
    var2 = np.var(sample2, ddof=1)

    # Calculate the F-statistic (larger variance / smaller variance)
    if var1 > var2:
        f_stat = var1 / var2
    else:
        f_stat = var2 / var1

    # Degrees of freedom
    df1 = len(sample1) - 1  # Degrees of freedom for sample 1
    df2 = len(sample2) - 1  # Degrees of freedom for sample 2

    # Perform the F-test and get the p-value
    p_value = 2 * min(stats.f.cdf(f_stat, df1, df2), 1 - stats.f.cdf(f_stat, df1, df2))  # Two-tailed test

    return f_stat, p_value

# Example data: Two random samples
np.random.seed(42)
sample1 = np.random.normal(loc=10, scale=5, size=50)  # Sample 1 with mean=10, std=5
sample2 = np.random.normal(loc=10, scale=10, size=50)  # Sample 2 with mean=10, std=10

# Perform F-test
f_stat, p_value = f_test(sample1, sample2)

# Display Results
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("\nReject the null hypothesis: The variances of the two populations are significantly different.")
else:
    print("\nFail to reject the null hypothesis: The variances of the two populations are equal.")
# Out:
# F-statistic: 3.5077
# P-value: 0.0000
#
# Reject the null hypothesis: The variances of the two populations are significantly different.

# %%
#17.Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results?


import numpy as np
import scipy.stats as stats

def perform_anova(*groups):
    """
    Perform one-way ANOVA test to compare means between multiple groups.

    Parameters:
    - groups: The groups to be compared (each group is a list or numpy array)

    Returns:
    - f_stat: F-statistic
    - p_value: P-value for the test
    """
    # Perform the one-way ANOVA test
    f_stat, p_value = stats.f_oneway(*groups)

    return f_stat, p_value

# Example data: Three independent groups with different sample means
group1 = np.random.normal(loc=50, scale=10, size=30)  # Group 1 (mean = 50, std = 10)
group2 = np.random.normal(loc=55, scale=10, size=30)  # Group 2 (mean = 55, std = 10)
group3 = np.random.normal(loc=60, scale=10, size=30)  # Group 3 (mean = 60, std = 10)

# Perform the ANOVA test
f_stat, p_value = perform_anova(group1, group2, group3)

# Display Results
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("\nReject the null hypothesis: There is a significant difference between the group means.")
else:
    print("\nFail to reject the null hypothesis: There is no significant difference between the group means.")
# Out:
# F-statistic: 9.6299
# P-value: 0.0002
#
# Reject the null hypothesis: There is a significant difference between the group means.

# %%
#18.Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results?


import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def perform_anova(*groups):
    """
    Perform one-way ANOVA test to compare means between multiple groups.

    Parameters:
    - groups: The groups to be compared (each group is a list or numpy array)

    Returns:
    - f_stat: F-statistic
    - p_value: P-value for the test
    """
    # Perform the one-way ANOVA test
    f_stat, p_value = stats.f_oneway(*groups)

    return f_stat, p_value

# Example data: Three independent groups with different sample means
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)  # Group 1 (mean = 50, std = 10)
group2 = np.random.normal(loc=55, scale=10, size=30)  # Group 2 (mean = 55, std = 10)
group3 = np.random.normal(loc=60, scale=10, size=30)  # Group 3 (mean = 60, std = 10)

# Perform the ANOVA test
f_stat, p_value = perform_anova(group1, group2, group3)

# Display Results
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("\nReject the null hypothesis: There is a significant difference between the group means.")
else:
    print("\nFail to reject the null hypothesis: There is no significant difference between the group means.")

# Plotting the boxplot for the groups
plt.figure(figsize=(8, 6))
plt.boxplot([group1, group2, group3], labels=['Group 1', 'Group 2', 'Group 3'], patch_artist=True,
            boxprops=dict(facecolor='skyblue', color='blue'), flierprops=dict(markerfacecolor='red', marker='o', markersize=6))
plt.title("One-Way ANOVA: Comparison of Means Between Groups")
plt.ylabel("Values")
plt.xlabel("Groups")
plt.grid(True)
plt.show()
# Out:
# F-statistic: 12.2095
# P-value: 0.0000
#
# Reject the null hypothesis: There is a significant difference between the group means.
# <ipython-input-24-f0e60bb3e00f>:46: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2, group3], labels=['Group 1', 'Group 2', 'Group 3'], patch_artist=True,

# %%
#19.Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA?


import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def check_assumptions(*groups):
    """
    Check the assumptions for performing ANOVA (normality, independence, equal variance).

    Parameters:
    - groups: The groups to be checked (each group is a list or numpy array)

    Returns:
    - assumption_results: A dictionary with the results of the assumption checks
    """

    assumption_results = {}

    # 1. Normality Assumption - Shapiro-Wilk Test
    normality_results = {}
    for i, group in enumerate(groups):
        stat, p_value = stats.shapiro(group)  # Shapiro-Wilk test for normality
        normality_results[f"Group {i+1}"] = (stat, p_value)

    # Check if p-value is greater than 0.05 (fail to reject H0: the group is normal)
    assumption_results["Normality"] = {k: ("Normal" if p > 0.05 else "Not Normal") for k, (stat, p) in normality_results.items()}

    # 2. Equal Variance Assumption - Levene's Test
    stat, p_value = stats.levene(*groups)  # Levene's test for equal variances
    assumption_results["Equal Variance (Levene's Test)"] = ("Equal Variance" if p_value > 0.05 else "Not Equal Variance")

    # 3. Independence Assumption
    # Independence cannot be tested statistically, but we can assume independence if data is randomly sampled
    assumption_results["Independence"] = "Assumed Random Sampling"

    return assumption_results

# Example data: Three independent groups with different sample means
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)  # Group 1 (mean = 50, std = 10)
group2 = np.random.normal(loc=55, scale=10, size=30)  # Group 2 (mean = 55, std = 10)
group3 = np.random.normal(loc=60, scale=10, size=30)  # Group 3 (mean = 60, std = 10)

# Check assumptions
assumptions = check_assumptions(group1, group2, group3)

# Display the results of the assumption checks
print("Assumption Check Results:")
for assumption, result in assumptions.items():
    print(f"{assumption}:")
    if isinstance(result, dict):  # For normality
        for group, status in result.items():
            print(f"  {group}: {status}")
    else:
        print(f"  {result}")

# Plot histograms for visual inspection of normality
plt.figure(figsize=(10, 6))
plt.subplot(1, 3, 1)
plt.hist(group1, bins=10, color='skyblue', edgecolor='black')
plt.title('Group 1 Histogram')

plt.subplot(1, 3, 2)
plt.hist(group2, bins=10, color='lightgreen', edgecolor='black')
plt.title('Group 2 Histogram')

plt.subplot(1, 3, 3)
plt.hist(group3, bins=10, color='lightcoral', edgecolor='black')
plt.title('Group 3 Histogram')

plt.tight_layout()
plt.show()
# Out:
# Assumption Check Results:
# Normality:
#   Group 1: Normal
#   Group 2: Normal
#   Group 3: Normal
# Equal Variance (Levene's Test):
#   Equal Variance
# Independence:
#   Assumed Random Sampling

# %%
#20.Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results?


import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns

# Simulate data for two-way ANOVA
np.random.seed(42)

# Factors and dependent variable
gender = ['Male', 'Female']
treatment = ['Drug', 'Placebo']

# Group means for each combination of factors
mean_dict = {
    ('Male', 'Drug'): 75,
    ('Male', 'Placebo'): 70,
    ('Female', 'Drug'): 80,
    ('Female', 'Placebo'): 65
}

# Simulate performance scores with random noise
n = 30  # Number of samples per group
data = []

for g in gender:
    for t in treatment:
        for _ in range(n):
            score = np.random.normal(mean_dict[(g, t)], 5)  # Adding noise
            data.append([g, t, score])

# Create DataFrame
df = pd.DataFrame(data, columns=['Gender', 'Treatment', 'Performance'])

# Perform Two-Way ANOVA using OLS (Ordinary Least Squares)
model = ols('Performance ~ C(Gender) * C(Treatment)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

# Display ANOVA table
print(anova_table)

# Interpretation
alpha = 0.05  # Significance level
print("\nInterpretation:")
for factor in anova_table.index:
    p_value = anova_table.loc[factor, 'PR(>F)']
    if p_value < alpha:
        print(f"{factor}: Significant effect (p < {alpha})")
    else:
        print(f"{factor}: No significant effect (p >= {alpha})")

# Visualize the interaction effect
plt.figure(figsize=(8, 6))
sns.pointplot(x='Treatment', y='Performance', hue='Gender', data=df, markers="o", linestyles='-', ci=None)
plt.title("Interaction Between Treatment and Gender on Performance")
plt.xlabel("Treatment")
plt.ylabel("Performance Score")
plt.legend(title="Gender")
plt.grid(True)
plt.show()
# Out:
#                              sum_sq     df           F        PR(>F)
# C(Gender)                 17.094240    1.0    0.784375  3.776386e-01
# C(Treatment)            2949.442777    1.0  135.336261  3.340873e-21
# C(Gender):C(Treatment)   826.970152    1.0   37.945828  1.080161e-08
# Residual                2528.039115  116.0         NaN           NaN
#
# Interpretation:
# C(Gender): No significant effect (p >= 0.05)
# C(Treatment): Significant effect (p < 0.05)
# C(Gender):C(Treatment): Significant effect (p < 0.05)
# Residual: No significant effect (p >= 0.05)
# <ipython-input-26-ff9015dceced>:58: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(x='Treatment', y='Performance', hue='Gender', data=df, markers="o", linestyles='-', ci=None)

# %%
#21.Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing?


import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def visualize_f_distribution(df1_values, df2_values, x_range=(0, 5), num_points=1000):
    """
    Visualizes the F-distribution for different degrees of freedom (df1 and df2).

    Parameters:
    - df1_values: List of numerator degrees of freedom.
    - df2_values: List of denominator degrees of freedom.
    - x_range: Range of x-axis (the F-statistic values).
    - num_points: Number of points to plot.
    """
    x = np.linspace(x_range[0], x_range[1], num_points)

    plt.figure(figsize=(10, 6))

    # Plot the F-distribution for different degrees of freedom (df1 and df2)
    for df1 in df1_values:
        for df2 in df2_values:
            y = stats.f.pdf(x, df1, df2)  # Probability density function of the F-distribution
            plt.plot(x, y, label=f'df1={df1}, df2={df2}')

    # Labels and title
    plt.title("F-distribution for Different Degrees of Freedom", fontsize=14)
    plt.xlabel("F-statistic", fontsize=12)
    plt.ylabel("Density", fontsize=12)
    plt.legend(title="Degrees of Freedom", loc='upper right')
    plt.grid(True)
    plt.show()

# Define different degrees of freedom (df1, df2)
df1_values = [2, 5, 10]  # Numerator degrees of freedom
df2_values = [10, 20, 30]  # Denominator degrees of freedom

# Visualize the F-distribution
visualize_f_distribution(df1_values, df2_values)

# %%
#22.Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means?


import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# Simulate data for three groups
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)  # Group 1: mean=50, std=10
group2 = np.random.normal(loc=55, scale=12, size=30)  # Group 2: mean=55, std=12
group3 = np.random.normal(loc=60, scale=15, size=30)  # Group 3: mean=60, std=15

# Perform One-Way ANOVA
f_statistic, p_value = stats.f_oneway(group1, group2, group3)

# Print the ANOVA result
print(f"F-statistic: {f_statistic}")
print(f"P-value: {p_value}")

# Interpret the result
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the group means.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the group means.")

# Create a boxplot to visualize the group comparisons
plt.figure(figsize=(8, 6))
sns.boxplot(data=[group1, group2, group3],
            width=0.5,
            palette="Set3")

# Customize the plot
plt.title('One-Way ANOVA: Comparison of Group Means', fontsize=14)
plt.xlabel('Group', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.xticks([0, 1, 2], ['Group 1', 'Group 2', 'Group 3'])
plt.grid(True)
plt.show()
# Out:
# F-statistic: 7.704273918844895
# P-value: 0.000830734883725171
# Reject the null hypothesis: There is a significant difference between the group means.

# %%
#23.Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means?


import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Step 1: Simulate random data from a normal distribution
np.random.seed(42)

# Group 1: Mean = 50, Standard deviation = 10, Sample size = 100
group1 = np.random.normal(loc=50, scale=10, size=100)

# Group 2: Mean = 55, Standard deviation = 12, Sample size = 100
group2 = np.random.normal(loc=55, scale=12, size=100)

# Step 2: Perform a two-sample t-test
t_statistic, p_value = stats.ttest_ind(group1, group2)

# Step 3: Print the results
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")

# Step 4: Interpret the result
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the means.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the means.")

# Step 5: Visualize the data with histograms
plt.figure(figsize=(10, 6))
plt.hist(group1, alpha=0.6, label='Group 1 (Mean=50)', bins=15)
plt.hist(group2, alpha=0.6, label='Group 2 (Mean=55)', bins=15)
plt.title('Distribution of Data from Two Groups', fontsize=14)
plt.xlabel('Value', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# T-statistic: -4.316398519082446
# P-value: 2.5039591073845923e-05
# Reject the null hypothesis: There is a significant difference between the means.

# %%
#24.Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results?


import numpy as np
import scipy.stats as stats

# Step 1: Simulate sample data
np.random.seed(42)

# Sample data: 100 observations, assumed population variance = 25
sample_data = np.random.normal(loc=50, scale=np.sqrt(25), size=100)

# Step 2: Hypothesized population variance (sigma^2_0)
sigma_squared_0 = 25  # Hypothesized population variance

# Step 3: Calculate sample variance (s^2)
sample_variance = np.var(sample_data, ddof=1)  # Use ddof=1 for sample variance
sample_size = len(sample_data)

# Step 4: Calculate the chi-square test statistic
chi_square_statistic = (sample_size - 1) * sample_variance / sigma_squared_0

# Step 5: Find the p-value for two-tailed test
# Degrees of freedom = sample_size - 1
df = sample_size - 1
p_value = 2 * min(stats.chi2.cdf(chi_square_statistic, df), 1 - stats.chi2.cdf(chi_square_statistic, df))

# Step 6: Print the results
print(f"Sample Variance: {sample_variance}")
print(f"Chi-Square Statistic: {chi_square_statistic}")
print(f"P-value: {p_value}")

# Step 7: Interpretation based on alpha level (0.05)
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The population variance is significantly different from the hypothesized value.")
else:
    print("Fail to reject the null hypothesis: The population variance is not significantly different from the hypothesized value.")
# Out:
# Sample Variance: 20.619247340753994
# Chi-Square Statistic: 81.65221946938581
# P-value: 0.20582515441893592
# Fail to reject the null hypothesis: The population variance is not significantly different from the hypothesized value.

# %%
#25.Write a Python script to perform a Z-test for comparing proportions between two datasets or groups?


import numpy as np
import scipy.stats as stats

# Sample data
# Group 1: 100 successes out of 200 trials
# Group 2: 120 successes out of 250 trials
successes_group1 = 100
trials_group1 = 200
successes_group2 = 120
trials_group2 = 250

# Step 1: Calculate the sample proportions
p_hat_1 = successes_group1 / trials_group1
p_hat_2 = successes_group2 / trials_group2

# Step 2: Calculate the pooled proportion
p_pooled = (successes_group1 + successes_group2) / (trials_group1 + trials_group2)

# Step 3: Calculate the Z-statistic
z_statistic = (p_hat_1 - p_hat_2) / np.sqrt(p_pooled * (1 - p_pooled) * (1 / trials_group1 + 1 / trials_group2))

# Step 4: Calculate the p-value (two-tailed test)
p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))

# Step 5: Print the results
print(f"Z-statistic: {z_statistic}")
print(f"P-value: {p_value}")

# Step 6: Interpret the result
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: The proportions are significantly different.")
else:
    print("Fail to reject the null hypothesis: The proportions are not significantly different.")
# Out:
# Z-statistic: 0.42174116783665033
# P-value: 0.6732139520792668
# Fail to reject the null hypothesis: The proportions are not significantly different.

# %%
#26.Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results?


import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Step 1: Simulate random data
np.random.seed(42)

# Group 1: Variance = 20, Sample size = 50
group1 = np.random.normal(loc=50, scale=np.sqrt(20), size=50)

# Group 2: Variance = 30, Sample size = 50
group2 = np.random.normal(loc=50, scale=np.sqrt(30), size=50)

# Step 2: Calculate sample variances
var_group1 = np.var(group1, ddof=1)
var_group2 = np.var(group2, ddof=1)

# Step 3: Calculate the F-statistic (larger variance / smaller variance)
F_statistic = var_group1 / var_group2 if var_group1 > var_group2 else var_group2 / var_group1

# Step 4: Degrees of freedom
df1 = len(group1) - 1
df2 = len(group2) - 1

# Step 5: Calculate the p-value for the F-distribution
p_value = 2 * min(stats.f.cdf(F_statistic, df1, df2), 1 - stats.f.cdf(F_statistic, df1, df2))

# Step 6: Print results
print(f"Variance of Group 1: {var_group1}")
print(f"Variance of Group 2: {var_group2}")
print(f"F-statistic: {F_statistic}")
print(f"P-value: {p_value}")

# Step 7: Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The variances are significantly different.")
else:
    print("Fail to reject the null hypothesis: The variances are not significantly different.")

# Step 8: Visualize the data with boxplots
plt.figure(figsize=(8, 6))
plt.boxplot([group1, group2], labels=['Group 1', 'Group 2'], patch_artist=True)
plt.title('Boxplot of Group 1 and Group 2')
plt.ylabel('Value')
plt.grid(True)
plt.show()
# Out:
# Variance of Group 1: 17.43474788526187
# Variance of Group 2: 22.933325511844778
# F-statistic: 1.3153803922356126
# P-value: 0.3405506021326987
# Fail to reject the null hypothesis: The variances are not significantly different.
# <ipython-input-31-fac0d59813ca>:46: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2], labels=['Group 1', 'Group 2'], patch_artist=True)

# %%
#27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results.


import numpy as np
import scipy.stats as stats

# Step 1: Simulate observed data (rolling a 6-sided die 600 times)
np.random.seed(42)

observed_data = np.random.choice([1, 2, 3, 4, 5, 6], size=600)

# Step 2: Calculate the observed frequencies
observed_frequencies = [np.sum(observed_data == i) for i in range(1, 7)]

# Step 3: Define the expected frequencies (assuming a fair die, each face should appear 100 times)
expected_frequencies = [600 / 6] * 6  # 600 rolls, 6 possible outcomes

# Step 4: Perform the Chi-Square test for goodness of fit
chi2_statistic, p_value = stats.chisquare(observed_frequencies, expected_frequencies)

# Step 5: Print the results
print(f"Observed Frequencies: {observed_frequencies}")
print(f"Expected Frequencies: {expected_frequencies}")
print(f"Chi-Square Statistic: {chi2_statistic}")
print(f"P-value: {p_value}")

# Step 6: Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: The observed frequencies do not match the expected frequencies.")
else:
    print("Fail to reject the null hypothesis: The observed frequencies match the expected frequencies.")
# Out:
# Observed Frequencies: [110, 95, 93, 113, 94, 95]
# Expected Frequencies: [100.0, 100.0, 100.0, 100.0, 100.0, 100.0]
# Chi-Square Statistic: 4.039999999999999
# P-value: 0.5436714312709128
# Fail to reject the null hypothesis: The observed frequencies match the expected frequencies.
